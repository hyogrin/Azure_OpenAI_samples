# %% [markdown]
# ## Following is a demo on running PromptWizard under different scenarios

# %% [markdown]
# #### Set environment variables in [.env](.env) for LLM API calling

# %% [markdown]
# #### Import Dependencies

# %%
import sys

sys.path.insert(0, "../../")
import promptwizard
from promptwizard.glue.promptopt.instantiate import GluePromptOpt
from promptwizard.glue.promptopt.techniques.common_logic import (
    DatasetSpecificProcessing,
)
from promptwizard.glue.common.utils.file import save_jsonlist
from typing import Any
from tqdm import tqdm
from re import compile, findall
import os
from datasets import load_dataset
import yaml
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
def update_yaml_file(file_path, config_dict):

    with open(file_path, "r") as file:
        data = yaml.safe_load(file)

    for field, value in config_dict.items():
        data[field] = value

    with open(file_path, "w") as file:
        yaml.dump(data, file, default_flow_style=False)

    print("YAML file updated successfully!")

# %% [markdown]
# Set the paths

# %%
path_to_config = "configs"
promptopt_config_path = os.path.join(path_to_config, "promptopt_config.yaml")
setup_config_path = os.path.join(path_to_config, "setup_config.yaml")

# %% [markdown]
# ### Now let us consider the three scenarios with respect to availability of training data

# %% [markdown]
# #### Scenario 1 : We have no training data , but we also don't want in-context examples in final prompt

# %% [markdown]
# Set the configurations to generate mutations

# %%
file_path = "configs/promptopt_config.yaml"
# Set the following based on the use case
config_dict = {
    "task_description": "You are a mathematics expert. You will be given a mathematics problem which you need to solve",
    "base_instruction": "Lets think step by step.",
    "mutation_rounds": 5,
}
update_yaml_file(file_path, config_dict)
# Out:
# YAML file updated successfully!

# %% [markdown]
# Create an object for calling prompt optimization and inference functionalities

# %%
gp = GluePromptOpt(
    promptopt_config_path, setup_config_path, dataset_jsonl=None, data_processor=None
)
# Out:
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 5), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 25), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================

# %% [markdown]
# Call the optimization function

# %%
best_prompt, expert_profile = gp.get_best_prompt(
    use_examples=False,
    run_without_train_examples=True,
    generate_synthetic_examples=False,
)
# Out:
# Mutating Task Description....
# Iterations completed:   0%|          | 0/3 [00:00<?, ?it/s]
# ======================================================================================================================================================
#  + Starting iteration: 1
#  current_base_instruction: Lets think step by step.
# === Using Azure OpenAI ===
# mutation_round=0 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step. <END>
# <START> We should analyze this problem incrementally. <END>
# <START> Let's approach this systematically, one step at a time. <END>
# <START> We can tackle this by considering each part step by step. <END>
# <START> Let's methodically think through this problem, step by step. <END>
# === Using Azure OpenAI ===
# mutation_round=1 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step. <END>
# <START> We should analyze this problem incrementally. <END>
# <START> Let's approach this systematically, one step at a time. <END>
# <START> We can tackle this by considering each part step by step. <END>
# <START> Let's proceed through this problem in a methodical manner, step by step. <END>
# === Using Azure OpenAI ===
# mutation_round=2 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step. <END>
# <START> We should analyze this problem incrementally. <END>
# <START> Let's approach this systematically, one step at a time. <END>
# <START> We can tackle this by considering each part step by step. <END>
# <START> Let's proceed through this problem in a methodical manner, step by step. <END>
# === Using Azure OpenAI ===
# mutation_round=3 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and resolve this issue. <END>
# === Using Azure OpenAI ===
# mutation_round=4 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# === Using Azure OpenAI ===
# mutation_round=5 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# Optimization Finished...
#
# Possible prompt variations:
# === Using Azure OpenAI ===
# === Using Azure OpenAI ===
# _______________________________________________________________________
#
# Variations 1:
# Expert Profile:
# You are a mathematics expert with a strong foundation in various branches of mathematics, including algebra, geometry, calculus, and statistics. Your analytical skills and problem-solving abilities are exceptional, allowing you to tackle a wide range of mathematical problems with ease. You have a deep understanding of mathematical concepts and theories, which enables you to approach problems methodically and efficiently. Whether the problem involves complex equations, geometric figures, or statistical analysis, you can break it down into manageable steps and provide clear, logical solutions. Your experience in teaching and tutoring mathematics has honed your ability to explain concepts in a way that is accessible and understandable to others. You are equipped with the tools and knowledge necessary to solve the given mathematics problem accurately and effectively, ensuring that your solution is not only correct but also well-reasoned.:
# Prompt:
# You are a mathematics expert. You will be given a mathematics problem which you need to solve
# Lets think step by step.
#
#
# For each question present the reasoning followed by the correct answer.
# Keywords: mathematics, expert, problem-solving, step-by-step, logical reasoning
# === Using Azure OpenAI ===
# === Using Azure OpenAI ===
# _______________________________________________________________________
#
# Variations 2:
# Expert Profile:
# You are a mathematics expert with a strong foundation in various branches of mathematics, including algebra, geometry, calculus, and statistics. Your analytical skills and problem-solving abilities are exceptional, allowing you to tackle a wide range of mathematical problems with ease. You have a deep understanding of mathematical concepts and theories, which enables you to approach problems methodically and efficiently. Whether the problem involves complex equations, geometric figures, or statistical analysis, you can break it down into manageable steps and provide clear, logical solutions. Your experience in teaching and tutoring mathematics has honed your ability to explain concepts in a way that is accessible and understandable to others. You are equipped with the tools and knowledge necessary to solve the given mathematics problem accurately and effectively, ensuring that your solution is not only correct but also well-reasoned.:
# Prompt:
#  Let's break this down step by step.
#
#
# For each question present the reasoning followed by the correct answer.
# Keywords: mathematics, expert, problem-solving, step-by-step, logical reasoning
# === Using Azure OpenAI ===
# === Using Azure OpenAI ===
# _______________________________________________________________________
#
# Variations 3:
# Expert Profile:
# You are a mathematics expert with a strong foundation in various branches of mathematics, including algebra, geometry, calculus, and statistics. Your analytical skills and problem-solving abilities are exceptional, allowing you to tackle a wide range of mathematical problems with ease. You have a deep understanding of mathematical concepts and theories, which enables you to approach problems methodically and efficiently. Whether the problem involves complex equations, geometric figures, or statistical analysis, you can break it down into manageable steps and provide clear, logical solutions. Your experience in teaching and tutoring mathematics has honed your ability to explain concepts in a way that is accessible and understandable to others. You are equipped with the tools and knowledge necessary to solve the given mathematics problem accurately and effectively, ensuring that your solution is not only correct but also well-reasoned.:
# Prompt:
#  We should analyze this problem incrementally.
#
#
# For each question present the reasoning followed by the correct answer.
# Keywords: mathematics, expert, problem-solving, step-by-step, logical reasoning
# === Using Azure OpenAI ===
# === Using Azure OpenAI ===
# _______________________________________________________________________
#
# Variations 4:
# Expert Profile:
# You are a mathematics expert with a strong foundation in various branches of mathematics, including algebra, geometry, calculus, and statistics. Your analytical skills and problem-solving abilities are exceptional, allowing you to tackle a wide range of mathematical problems with ease. You have a deep understanding of mathematical concepts and theories, which enables you to approach problems methodically and efficiently. Whether the problem involves complex equations, geometric figures, or statistical analysis, you can break it down into manageable steps and provide clear, logical solutions. Your experience in teaching and tutoring mathematics has honed your ability to explain concepts in a way that is accessible and understandable to others. You are equipped with the tools and knowledge necessary to solve the given mathematics problem accurately and effectively, ensuring that your solution is not only correct but also well-reasoned.:
# Prompt:
#  Let's approach this systematically, one step at a time.
#
#
# For each question present the reasoning followed by the correct answer.
# Keywords: mathematics, expert, problem-solving, step-by-step, logical reasoning
# === Using Azure OpenAI ===
# === Using Azure OpenAI ===
# Iterations completed:   0%|          | 0/3 [00:34<?, ?it/s]
# Time taken to find best prompt: 34.757455825805664 sec
# _______________________________________________________________________
#
# Variations 5:
# Expert Profile:
# You are a mathematics expert with a strong foundation in various branches of mathematics, including algebra, geometry, calculus, and statistics. Your analytical skills and problem-solving abilities are exceptional, allowing you to tackle a wide range of mathematical problems with ease. You have a deep understanding of mathematical concepts and theories, which enables you to approach problems methodically and efficiently. Whether the problem involves complex equations, geometric figures, or statistical analysis, you can break it down into manageable steps and provide clear, logical solutions. Your experience in teaching and tutoring mathematics has honed your ability to explain concepts in a way that is accessible and understandable to others. You are equipped with the tools and knowledge necessary to solve the given mathematics problem accurately and effectively, ensuring that your solution is not only correct but also well-reasoned.:
# Prompt:
#  We can tackle this by considering each part step by step.
#
#
# For each question present the reasoning followed by the correct answer.
# Keywords: mathematics, expert, problem-solving, step-by-step, logical reasoning

# %% [markdown]
# Output : Five mutated prompts are printed on the termial as shown below :

# %% [markdown]
# #### Scenario 2 : We have no training data , but we also want in-context examples in final prompt

# %% [markdown]
# This scenario has two steps
# - Genrate synthetic data
# - Optimize prompts using synthetic data

# %% [markdown]
# STEP 1 : Generate synthetic data

# %% [markdown]
# Set the configurations to first generate synthetic training data. \
# Any number of synthetic examples can be generated and then used for optimizing prompts as mentioned in STEP 2

# %%
file_path = "configs/promptopt_config.yaml"
# Set the number of synthetic training examples to be generated
config_dict = {"num_train_examples": 20}
update_yaml_file(file_path, config_dict)
# Out:
# YAML file updated successfully!

# %%
promptopt_config_path, setup_config_path
# Out:
# ('configs/promptopt_config.yaml', 'configs/setup_config.yaml')

# %%
gp = GluePromptOpt(
    promptopt_config_path, setup_config_path, dataset_jsonl=None, data_processor=None
)
# Out:
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 5), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 25), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 5), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 25), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 5), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 25), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================

# %% [markdown]
# Call the function to generate synthetic examples, which are saved in train.jsonl

# %%
best_prompt, expert_profile = gp.get_best_prompt(
    use_examples=False,
    run_without_train_examples=False,
    generate_synthetic_examples=True,
)
# Out:
# Generating Sythetic Examples....
# === Using Azure OpenAI ===
# === Using Azure OpenAI ===
# Time taken to find best prompt: 26.43803381919861 sec
# Time taken to find best prompt: 26.43803381919861 sec
# Time taken to find best prompt: 26.43803381919861 sec
# Synthetic examples saved at train.jsonl....

# %%
expert_profile
# Out:
# ''

# %% [markdown]
# STEP 2 : Optimize prompts using synthetic data

# %% [markdown]
# Create a dataset specific class and define the required functions

# %%
class GSM8k(DatasetSpecificProcessing):

    def dataset_to_jsonl(self, dataset_jsonl: str, **kwargs: Any) -> None:
        def extract_answer_from_output(completion):
            # Your functions for metrics and prompt building
            ans_re = compile(r"#### (\-?[0-9\.\,]+)")
            self.INVALID_ANS = "[invalid]"

            match = ans_re.search(completion)
            if match:
                match_str = match.group(1).strip()
                match_str = match_str.replace(",", "")
                return match_str
            else:
                return self.INVALID_ANS

        examples_set = []

        for _, sample in tqdm(enumerate(kwargs["dataset"]), desc="Evaluating samples"):
            example = {
                DatasetSpecificProcessing.QUESTION_LITERAL: sample["question"],
                DatasetSpecificProcessing.ANSWER_WITH_REASON_LITERAL: sample["answer"],
                DatasetSpecificProcessing.FINAL_ANSWER_LITERAL: extract_answer_from_output(
                    sample["answer"]
                ),
            }
            examples_set.append(example)

        save_jsonlist(dataset_jsonl, examples_set, "w")

    def extract_final_answer(self, answer: str):

        if not answer:
            return self.INVALID_ANS

        model_pred = answer.lower()
        preds = model_pred.split(self.ANSWER_START.lower())
        answer_flag = True if len(preds) > 1 else False

        pred = preds[-1].replace(",", "")
        pred = [s for s in findall(r"-?\d+\.?\d*", pred)]

        if len(pred) == 0:
            return self.INVALID_ANS

        if answer_flag:
            # choose the first element in list
            pred = pred[0]
        else:
            # choose the last element in list
            pred = pred[-1]

        # (For arithmetic tasks) if a word ends with period, it will be omitted ...
        if pred[-1] == ".":
            pred = pred[:-1]
        return pred

# %%
class GSM8k(DatasetSpecificProcessing):

    def dataset_to_jsonl(self, dataset_jsonl: str, **kwargs: Any) -> None:
        def extract_answer_from_output(completion):
            # Your functions for metrics and prompt building
            ans_re = compile(r"#### (\-?[0-9\.\,]+)")
            self.INVALID_ANS = "[invalid]"

            match = ans_re.search(completion)
            if match:
                match_str = match.group(1).strip()
                match_str = match_str.replace(",", "")
                return match_str
            else:
                return self.INVALID_ANS

        examples_set = []

        for _, sample in tqdm(enumerate(kwargs["dataset"]), desc="Evaluating samples"):
            example = {
                DatasetSpecificProcessing.QUESTION_LITERAL: sample["question"],
                DatasetSpecificProcessing.ANSWER_WITH_REASON_LITERAL: sample["answer"],
                DatasetSpecificProcessing.FINAL_ANSWER_LITERAL: extract_answer_from_output(
                    sample["answer"]
                ),
            }
            examples_set.append(example)

        save_jsonlist(dataset_jsonl, examples_set, "w")

    def extract_final_answer(self, answer: str):

        if not answer:
            return self.INVALID_ANS

        model_pred = answer.lower()
        preds = model_pred.split(self.ANSWER_START.lower())
        answer_flag = True if len(preds) > 1 else False

        pred = preds[-1].replace(",", "")
        pred = [s for s in findall(r"-?\d+\.?\d*", pred)]

        if len(pred) == 0:
            return self.INVALID_ANS

        if answer_flag:
            # choose the first element in list
            pred = pred[0]
        else:
            # choose the last element in list
            pred = pred[-1]

        # (For arithmetic tasks) if a word ends with period, it will be omitted ...
        if pred[-1] == ".":
            pred = pred[:-1]
        return pred
gsm8k_processor = GSM8k()

# %% [markdown]
# Set the configurations to optimize the prompt on the synthetic data

# %%
file_path = "configs/promptopt_config.yaml"
config_dict = {
    "task_description": "You are a mathematics expert. You will be given a mathematics problem which you need to solve",
    "base_instruction": "Lets think step by step.",
    "mutation_rounds": 2,
    "few_shot_count": 5,
    "generate_reasoning": True,
    "mutate_refine_iterations": 3,
    "seen_set_size": 20,
}
update_yaml_file(file_path, config_dict)
# Out:
# YAML file updated successfully!

# %% [markdown]
# Call the optimization function

# %%
gp = GluePromptOpt(
    promptopt_config_path,
    setup_config_path,
    dataset_jsonl="train_synthetic.jsonl",
    data_processor=gsm8k_processor,
)
best_prompt, expert_profile = gp.get_best_prompt(
    use_examples=True,
    run_without_train_examples=False,
    generate_synthetic_examples=False,
)
# Out:
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Setup configurations parameters: [('assistant_llm', AssistantLLM(prompt_opt='gpt-4o-mini')), ('description', None), ('dir_info', Dir(base_dir='logs', log_dir_name='glue_logs')), ('experiment_name', 'gsm8k'), ('mode', 'offline')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 2), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 20), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 2), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 20), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 2), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 20), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================
#
# Prompt Optimization parameters: [('answer_format', 'For each question present the reasoning followed by the correct answer.'), ('base_instruction', 'Lets think step by step.'), ('few_shot_count', 5), ('generate_expert_identity', True), ('generate_intent_keywords', False), ('generate_reasoning', True), ('max_eval_batches', 6), ('min_correct_count', 3), ('mutate_refine_iterations', 3), ('mutation_rounds', 2), ('num_train_examples', 20), ('prompt_technique_name', 'critique_n_refine'), ('questions_batch_size', 1), ('refine_instruction', True), ('refine_task_eg_iterations', 3), ('seen_set_size', 20), ('style_variation', 5), ('task_description', 'You are a mathematics expert. You will be given a mathematics problem which you need to solve'), ('top_n', 1), ('unique_model_id', 'gpt-4o-mini')]
#
# ======================================================================================================================================================
# Mutating Task Description....
# Iterations completed:   0%|          | 0/3 [00:00<?, ?it/s]
# ======================================================================================================================================================
#  + Starting iteration: 1
#  current_base_instruction: Lets think step by step.
#
# ======================================================================================================================================================
#  + Starting iteration: 1
#  current_base_instruction: Lets think step by step.
#
# ======================================================================================================================================================
#  + Starting iteration: 1
#  current_base_instruction: Lets think step by step.
#
# ======================================================================================================================================================
#  + Starting iteration: 1
#  current_base_instruction: Lets think step by step.
# === Using Azure OpenAI ===
# mutation_round=0 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# mutation_round=0 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# mutation_round=0 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# mutation_round=0 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# === Using Azure OpenAI ===
# mutation_round=1 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem step by step. <END>
# <START> We can solve this by considering each step in detail and progressing gradually. <END>
# <START> Let's take a methodical approach, examining the problem step by step to uncover the solution. <END>
# mutation_round=1 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem step by step. <END>
# <START> We can solve this by considering each step in detail and progressing gradually. <END>
# <START> Let's take a methodical approach, examining the problem step by step to uncover the solution. <END>
# mutation_round=1 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem step by step. <END>
# <START> We can solve this by considering each step in detail and progressing gradually. <END>
# <START> Let's take a methodical approach, examining the problem step by step to uncover the solution. <END>
# mutation_round=1 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem step by step. <END>
# <START> We can solve this by considering each step in detail and progressing gradually. <END>
# <START> Let's take a methodical approach, examining the problem step by step to uncover the solution. <END>
# === Using Azure OpenAI ===
# mutation_round=2 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# mutation_round=2 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# mutation_round=2 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# mutation_round=2 mutated_sample_prompt=You are given a task description and a prompt instruction and different styles known as meta prompts:
# [Task Description]: You are a mathematics expert. You will be given a mathematics problem which you need to solve
# [Meta Prompt]: How could I devise an experiment to help solve that problem?
# Make a list of ideas for solving this problem, and apply them one by one to the problem to see if any progress can be made.
# How could I measure progress on this problem?
# How can I simplify the problem so that it is easier to solve?
# What are the key assumptions underlying this problem?
# Now you need to generate 5 variations of following Instruction adaptively mixing meta prompt while keeping similar semantic meaning.
# Make sure to wrap each generated prompt with <START> and <END>
# [Prompt Instruction]: Lets think step by step.
# [Generated Prompts]:
# mutated_prompt_generation=<START> Let's break this down step by step to find a solution. <END>
# <START> We should analyze this problem incrementally, addressing each part one at a time. <END>
# <START> Let's approach this systematically, tackling each aspect of the problem one by one. <END>
# <START> We can solve this by considering each step carefully and methodically. <END>
# <START> Let's take a step-by-step approach to understand and solve this problem. <END>
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is the intersection of sets A = {1, 2, 3} and B = {2, 3, 4}?', 'answer': 'The intersection of two sets includes elements that are common to both sets. Here, the common elements are 2 and 3. Thus, A ∩ B = {2, 3}. <ANS_START>{2, 3}<ANS_END>', 'final_answer': '{2, 3}'}]
# critique_example_set, correct_count
# [{'question': 'What is the intersection of sets A = {1, 2, 3} and B = {2, 3, 4}?', 'answer': 'The intersection of two sets includes elements that are common to both sets. Here, the common elements are 2 and 3. Thus, A ∩ B = {2, 3}. <ANS_START>{2, 3}<ANS_END>', 'final_answer': '{2, 3}'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is the slope of the line represented by the equation 3y - 6x = 12?', 'answer': 'First, we rewrite the equation in slope-intercept form (y = mx + b): 3y = 6x + 12, so y = 2x + 4. The slope (m) is 2. <ANS_START>2<ANS_END>', 'final_answer': '2'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'If each pizza costs $8, how many pizzas can you buy with $40?', 'answer': 'To find the number of pizzas, we divide the total amount by the cost per pizza: Number of pizzas = $40 / $8 = 5. <ANS_START>5<ANS_END>', 'final_answer': '5'}]
# critique_example_set, correct_count
# [] 2
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Find the median of the following set of numbers: 3, 1, 4, 2, 5.', 'answer': 'First, we arrange the numbers in ascending order: 1, 2, 3, 4, 5. Since there are 5 numbers (an odd count), the median is the middle number, which is 3. <ANS_START>3<ANS_END>', 'final_answer': '3'}]
# critique_example_set, correct_count
# [] 3
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]
# critique_example_set, correct_count
# [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Find the median of the following set of numbers: 3, 1, 4, 2, 5.', 'answer': 'First, we arrange the numbers in ascending order: 1, 2, 3, 4, 5. Since there are 5 numbers (an odd count), the median is the middle number, which is 3. <ANS_START>3<ANS_END>', 'final_answer': '3'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}]
# critique_example_set, correct_count
# [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}] 1
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Solve for x: x^2 - 5x + 6 = 0.', 'answer': 'We can factor the quadratic equation: (x - 2)(x - 3) = 0. Setting each factor to zero gives us x - 2 = 0 or x - 3 = 0. Thus, x = 2 or x = 3. <ANS_START>2, 3<ANS_END>', 'final_answer': '2, 3'}]
# critique_example_set, correct_count
# [{'question': 'Solve for x: x^2 - 5x + 6 = 0.', 'answer': 'We can factor the quadratic equation: (x - 2)(x - 3) = 0. Setting each factor to zero gives us x - 2 = 0 or x - 3 = 0. Thus, x = 2 or x = 3. <ANS_START>2, 3<ANS_END>', 'final_answer': '2, 3'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Graph the equation y = -x + 3.', 'answer': 'To graph this line, we find the y-intercept (0, 3) and the slope (-1). From (0, 3), we go down 1 unit and right 1 unit to find another point (1, 2). Connecting these points gives the graph of the line. <ANS_START>Graph of y = -x + 3<ANS_END>', 'final_answer': 'Graph of y = -x + 3'}]
# critique_example_set, correct_count
# [{'question': 'Graph the equation y = -x + 3.', 'answer': 'To graph this line, we find the y-intercept (0, 3) and the slope (-1). From (0, 3), we go down 1 unit and right 1 unit to find another point (1, 2). Connecting these points gives the graph of the line. <ANS_START>Graph of y = -x + 3<ANS_END>', 'final_answer': 'Graph of y = -x + 3'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Find the greatest common divisor (GCD) of 24 and 36.', 'answer': 'The factors of 24 are 1, 2, 3, 4, 6, 8, 12, 24. The factors of 36 are 1, 2, 3, 4, 6, 9, 12, 18, 36. The greatest common factor is 12. <ANS_START>12<ANS_END>', 'final_answer': '12'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Calculate the integral of f(x) = 3x^2 from x = 1 to x = 2.', 'answer': 'The integral of f(x) = 3x^2 is F(x) = x^3. Evaluating from 1 to 2: F(2) - F(1) = 2^3 - 1^3 = 8 - 1 = 7. <ANS_START>7<ANS_END>', 'final_answer': '7'}]
# critique_example_set, correct_count
# [] 2
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is 5 + 3 - 2 × 4?', 'answer': 'First, we perform the multiplication: 2 × 4 = 8. Then, we substitute this back into the equation: 5 + 3 - 8. Next, we perform the addition: 5 + 3 = 8. Finally, we subtract: 8 - 8 = 0. <ANS_START>0<ANS_END>', 'final_answer': '0'}]
# critique_example_set, correct_count
# [] 3
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}]
# critique_example_set, correct_count
# [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Model the growth of a population that starts at 100 and grows at a rate of 5% per year.', 'answer': 'The population after t years can be modeled by the formula P(t) = P0(1 + r)^t. Here, P(t) = 100(1 + 0.05)^t. For t = 3, P(3) = 100(1.05)^3 ≈ 115.76. <ANS_START>115.76<ANS_END>', 'final_answer': '115.76'}]
# critique_example_set, correct_count
# [{'question': 'Model the growth of a population that starts at 100 and grows at a rate of 5% per year.', 'answer': 'The population after t years can be modeled by the formula P(t) = P0(1 + r)^t. Here, P(t) = 100(1 + 0.05)^t. For t = 3, P(3) = 100(1.05)^3 ≈ 115.76. <ANS_START>115.76<ANS_END>', 'final_answer': '115.76'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is the value of 3^4?', 'answer': 'We calculate 3^4 as 3 × 3 × 3 × 3 = 81. <ANS_START>81<ANS_END>', 'final_answer': '81'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]
# critique_example_set, correct_count
# [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}] 1
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'A car travels 120 miles in 2 hours. How far will it travel in 5 hours at the same speed?', 'answer': 'First, we find the speed of the car: Speed = Distance/Time = 120 miles / 2 hours = 60 miles/hour. Now, we calculate the distance for 5 hours: Distance = Speed × Time = 60 miles/hour × 5 hours = 300 miles. <ANS_START>300<ANS_END>', 'final_answer': '300'}]
# critique_example_set, correct_count
# [{'question': 'A car travels 120 miles in 2 hours. How far will it travel in 5 hours at the same speed?', 'answer': 'First, we find the speed of the car: Speed = Distance/Time = 120 miles / 2 hours = 60 miles/hour. Now, we calculate the distance for 5 hours: Distance = Speed × Time = 60 miles/hour × 5 hours = 300 miles. <ANS_START>300<ANS_END>', 'final_answer': '300'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is the area of a triangle with a base of 10 and a height of 5?', 'answer': 'The area of a triangle is given by the formula: Area = 1/2 × base × height. Substituting the values, we have Area = 1/2 × 10 × 5 = 25. <ANS_START>25<ANS_END>', 'final_answer': '25'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}]
# critique_example_set, correct_count
# [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}] 1
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Find the median of the following set of numbers: 3, 1, 4, 2, 5.', 'answer': 'First, we arrange the numbers in ascending order: 1, 2, 3, 4, 5. Since there are 5 numbers (an odd count), the median is the middle number, which is 3. <ANS_START>3<ANS_END>', 'final_answer': '3'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'Find the median of the following set of numbers: 3, 1, 4, 2, 5.', 'answer': 'First, we arrange the numbers in ascending order: 1, 2, 3, 4, 5. Since there are 5 numbers (an odd count), the median is the middle number, which is 3. <ANS_START>3<ANS_END>', 'final_answer': '3'}]
# critique_example_set, correct_count
# [] 2
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}]
# critique_example_set, correct_count
# [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}] 2
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'If you invest $200 at a 4% annual interest rate, how much will you have after 2 years with simple interest?', 'answer': 'The formula for simple interest is A = P(1 + rt), where P is the principal, r is the rate, and t is the time. Here, A = 200(1 + 0.04 × 2) = 200(1 + 0.08) = 200 × 1.08 = 216. <ANS_START>216<ANS_END>', 'final_answer': '216'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'If each pizza costs $8, how many pizzas can you buy with $40?', 'answer': 'To find the number of pizzas, we divide the total amount by the cost per pizza: Number of pizzas = $40 / $8 = 5. <ANS_START>5<ANS_END>', 'final_answer': '5'}]
# critique_example_set, correct_count
# [{'question': 'If each pizza costs $8, how many pizzas can you buy with $40?', 'answer': 'To find the number of pizzas, we divide the total amount by the cost per pizza: Number of pizzas = $40 / $8 = 5. <ANS_START>5<ANS_END>', 'final_answer': '5'}] 1
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}]
# critique_example_set, correct_count
# [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}] 0
# Loop completed
# === Using Azure OpenAI ===
# dataset_subset [{'question': 'If each pizza costs $8, how many pizzas can you buy with $40?', 'answer': 'To find the number of pizzas, we divide the total amount by the cost per pizza: Number of pizzas = $40 / $8 = 5. <ANS_START>5<ANS_END>', 'final_answer': '5'}]
# critique_example_set, correct_count
# [] 1
# === Using Azure OpenAI ===
# prompt_score_list [['You are a mathematics expert. You will be given a mathematics problem which you need to solve\nLets think step by step.', 0.0, [{'question': 'What is the intersection of sets A = {1, 2, 3} and B = {2, 3, 4}?', 'answer': 'The intersection of two sets includes elements that are common to both sets. Here, the common elements are 2 and 3. Thus, A ∩ B = {2, 3}. <ANS_START>{2, 3}<ANS_END>', 'final_answer': '{2, 3}'}]], [" Let's break this down step by step to find a solution. ", 1.0, [{'question': 'A car travels 120 miles in 2 hours. How far will it travel in 5 hours at the same speed?', 'answer': 'First, we find the speed of the car: Speed = Distance/Time = 120 miles / 2 hours = 60 miles/hour. Now, we calculate the distance for 5 hours: Distance = Speed × Time = 60 miles/hour × 5 hours = 300 miles. <ANS_START>300<ANS_END>', 'final_answer': '300'}]], [' We should analyze this problem incrementally, addressing each part one at a time. ', 0.0, [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]], [" Let's approach this systematically, tackling each aspect of the problem one by one. ", 0.5, [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}]], [' We can solve this by considering each step carefully and methodically. ', 0.0, [{'question': 'Solve for x: x^2 - 5x + 6 = 0.', 'answer': 'We can factor the quadratic equation: (x - 2)(x - 3) = 0. Setting each factor to zero gives us x - 2 = 0 or x - 3 = 0. Thus, x = 2 or x = 3. <ANS_START>2, 3<ANS_END>', 'final_answer': '2, 3'}]], [" Let's take a step-by-step approach to understand and solve this problem. ", 0.0, [{'question': 'Graph the equation y = -x + 3.', 'answer': 'To graph this line, we find the y-intercept (0, 3) and the slope (-1). From (0, 3), we go down 1 unit and right 1 unit to find another point (1, 2). Connecting these points gives the graph of the line. <ANS_START>Graph of y = -x + 3<ANS_END>', 'final_answer': 'Graph of y = -x + 3'}]], [" Let's break this down step by step to find a solution. ", 1.0, [{'question': 'What is the area of a triangle with a base of 10 and a height of 5?', 'answer': 'The area of a triangle is given by the formula: Area = 1/2 × base × height. Substituting the values, we have Area = 1/2 × 10 × 5 = 25. <ANS_START>25<ANS_END>', 'final_answer': '25'}]], [' We should analyze this problem incrementally, addressing each part one at a time. ', 0.0, [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}]], [" Let's approach this systematically, tackling each aspect of the problem step by step. ", 0.0, [{'question': 'Model the growth of a population that starts at 100 and grows at a rate of 5% per year.', 'answer': 'The population after t years can be modeled by the formula P(t) = P0(1 + r)^t. Here, P(t) = 100(1 + 0.05)^t. For t = 3, P(3) = 100(1.05)^3 ≈ 115.76. <ANS_START>115.76<ANS_END>', 'final_answer': '115.76'}]], [' We can solve this by considering each step in detail and progressing gradually. ', 0.5, [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]], [" Let's take a methodical approach, examining the problem step by step to uncover the solution. ", 0.0 ...
# prompt_score_list [['You are a mathematics expert. You will be given a mathematics problem which you need to solve\nLets think step by step.', 0.0, [{'question': 'What is the intersection of sets A = {1, 2, 3} and B = {2, 3, 4}?', 'answer': 'The intersection of two sets includes elements that are common to both sets. Here, the common elements are 2 and 3. Thus, A ∩ B = {2, 3}. <ANS_START>{2, 3}<ANS_END>', 'final_answer': '{2, 3}'}]], [" Let's break this down step by step to find a solution. ", 1.0, [{'question': 'A car travels 120 miles in 2 hours. How far will it travel in 5 hours at the same speed?', 'answer': 'First, we find the speed of the car: Speed = Distance/Time = 120 miles / 2 hours = 60 miles/hour. Now, we calculate the distance for 5 hours: Distance = Speed × Time = 60 miles/hour × 5 hours = 300 miles. <ANS_START>300<ANS_END>', 'final_answer': '300'}]], [' We should analyze this problem incrementally, addressing each part one at a time. ', 0.0, [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]], [" Let's approach this systematically, tackling each aspect of the problem one by one. ", 0.5, [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}]], [' We can solve this by considering each step carefully and methodically. ', 0.0, [{'question': 'Solve for x: x^2 - 5x + 6 = 0.', 'answer': 'We can factor the quadratic equation: (x - 2)(x - 3) = 0. Setting each factor to zero gives us x - 2 = 0 or x - 3 = 0. Thus, x = 2 or x = 3. <ANS_START>2, 3<ANS_END>', 'final_answer': '2, 3'}]], [" Let's take a step-by-step approach to understand and solve this problem. ", 0.0, [{'question': 'Graph the equation y = -x + 3.', 'answer': 'To graph this line, we find the y-intercept (0, 3) and the slope (-1). From (0, 3), we go down 1 unit and right 1 unit to find another point (1, 2). Connecting these points gives the graph of the line. <ANS_START>Graph of y = -x + 3<ANS_END>', 'final_answer': 'Graph of y = -x + 3'}]], [" Let's break this down step by step to find a solution. ", 1.0, [{'question': 'What is the area of a triangle with a base of 10 and a height of 5?', 'answer': 'The area of a triangle is given by the formula: Area = 1/2 × base × height. Substituting the values, we have Area = 1/2 × 10 × 5 = 25. <ANS_START>25<ANS_END>', 'final_answer': '25'}]], [' We should analyze this problem incrementally, addressing each part one at a time. ', 0.0, [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}]], [" Let's approach this systematically, tackling each aspect of the problem step by step. ", 0.0, [{'question': 'Model the growth of a population that starts at 100 and grows at a rate of 5% per year.', 'answer': 'The population after t years can be modeled by the formula P(t) = P0(1 + r)^t. Here, P(t) = 100(1 + 0.05)^t. For t = 3, P(3) = 100(1.05)^3 ≈ 115.76. <ANS_START>115.76<ANS_END>', 'final_answer': '115.76'}]], [' We can solve this by considering each step in detail and progressing gradually. ', 0.5, [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]], [" Let's take a methodical approach, examining the problem step by step to uncover the solution. ", 0.0 ...
# prompt_score_list [['You are a mathematics expert. You will be given a mathematics problem which you need to solve\nLets think step by step.', 0.0, [{'question': 'What is the intersection of sets A = {1, 2, 3} and B = {2, 3, 4}?', 'answer': 'The intersection of two sets includes elements that are common to both sets. Here, the common elements are 2 and 3. Thus, A ∩ B = {2, 3}. <ANS_START>{2, 3}<ANS_END>', 'final_answer': '{2, 3}'}]], [" Let's break this down step by step to find a solution. ", 1.0, [{'question': 'A car travels 120 miles in 2 hours. How far will it travel in 5 hours at the same speed?', 'answer': 'First, we find the speed of the car: Speed = Distance/Time = 120 miles / 2 hours = 60 miles/hour. Now, we calculate the distance for 5 hours: Distance = Speed × Time = 60 miles/hour × 5 hours = 300 miles. <ANS_START>300<ANS_END>', 'final_answer': '300'}]], [' We should analyze this problem incrementally, addressing each part one at a time. ', 0.0, [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]], [" Let's approach this systematically, tackling each aspect of the problem one by one. ", 0.5, [{'question': 'What is (2 + 3i) + (4 - 2i)?', 'answer': 'We add the real parts and the imaginary parts separately: (2 + 4) + (3i - 2i) = 6 + 1i. <ANS_START>6 + i<ANS_END>', 'final_answer': '6 + i'}]], [' We can solve this by considering each step carefully and methodically. ', 0.0, [{'question': 'Solve for x: x^2 - 5x + 6 = 0.', 'answer': 'We can factor the quadratic equation: (x - 2)(x - 3) = 0. Setting each factor to zero gives us x - 2 = 0 or x - 3 = 0. Thus, x = 2 or x = 3. <ANS_START>2, 3<ANS_END>', 'final_answer': '2, 3'}]], [" Let's take a step-by-step approach to understand and solve this problem. ", 0.0, [{'question': 'Graph the equation y = -x + 3.', 'answer': 'To graph this line, we find the y-intercept (0, 3) and the slope (-1). From (0, 3), we go down 1 unit and right 1 unit to find another point (1, 2). Connecting these points gives the graph of the line. <ANS_START>Graph of y = -x + 3<ANS_END>', 'final_answer': 'Graph of y = -x + 3'}]], [" Let's break this down step by step to find a solution. ", 1.0, [{'question': 'What is the area of a triangle with a base of 10 and a height of 5?', 'answer': 'The area of a triangle is given by the formula: Area = 1/2 × base × height. Substituting the values, we have Area = 1/2 × 10 × 5 = 25. <ANS_START>25<ANS_END>', 'final_answer': '25'}]], [' We should analyze this problem incrementally, addressing each part one at a time. ', 0.0, [{'question': 'Solve the compound inequality: 2 < x + 3 < 8.', 'answer': 'We can break this into two inequalities: 2 < x + 3 and x + 3 < 8. Solving the first gives x > -1, and the second gives x < 5. Thus, the solution is -1 < x < 5. <ANS_START>-1 < x < 5<ANS_END>', 'final_answer': '-1 < x < 5'}]], [" Let's approach this systematically, tackling each aspect of the problem step by step. ", 0.0, [{'question': 'Model the growth of a population that starts at 100 and grows at a rate of 5% per year.', 'answer': 'The population after t years can be modeled by the formula P(t) = P0(1 + r)^t. Here, P(t) = 100(1 + 0.05)^t. For t = 3, P(3) = 100(1.05)^3 ≈ 115.76. <ANS_START>115.76<ANS_END>', 'final_answer': '115.76'}]], [' We can solve this by considering each step in detail and progressing gradually. ', 0.5, [{'question': 'Prove that the sum of two even numbers is even.', 'answer': 'Let a and b be two even numbers. By definition, a = 2m and b = 2n for some integers m and n. The sum is a + b = 2m + 2n = 2(m + n), which is even since m + n is an integer. <ANS_START>Proven<ANS_END>', 'final_answer': 'Proven'}]], [" Let's take a methodical approach, examining the problem step by step to uncover the solution. ", 0.0 ...
# ...
#    - x = 60 + 360n (for n being any integer)
#    - x = 300 + 360n (for n being any integer)
#
# 6. **Final answer**: The specific solutions in the range of 0 to 360 degrees are 60 degrees and 300 degrees.
#
# Thus, the possible values of x in degrees are 60 and 300. <ANS_START>60<ANS_END>
#
# [Question] What is the intersection of sets A = {1, 2, 3, 5} and B = {2, 3, 4, 6}?
# [Answer] To find the intersection of sets A and B, we need to identify the elements that are common to both sets.
#
# 1. **Identify the elements of each set**:
#    - Set A contains the elements: {1, 2, 3, 5}
#    - Set B contains the elements: {2, 3, 4, 6}
#
# 2. **List the elements of Set A**:
#    - 1
#    - 2
#    - 3
#    - 5
#
# 3. **List the elements of Set B**:
#    - 2
#    - 3
#    - 4
#    - 6
#
# 4. **Compare the elements of both sets**:
#    - Check each element of Set A against the elements of Set B:
#      - 1 is not in Set B.
#      - 2 is in Set B.
#      - 3 is in Set B.
#      - 5 is not in Set B.
#
# 5. **Identify the common elements**:
#    - The elements that are found in both Set A and Set B are: 2 and 3.
#
# 6. **Conclusion**:
#    - The intersection of sets A and B is {2, 3}.
#
# However, since the task specifies to provide a single answer, we can choose one of the common elements. The answer can be represented as either 2 or 3.
#
# For the purpose of this task, I will provide the first common element found.
#
# [Answer]: 2 <ANS_START>2<ANS_END>
#
#
# For each question present the reasoning followed by the correct answer.
#
# Final best prompt: You are a mathematics expert. Please solve the following mathematics problem directly and provide the answer clearly, without unnecessary elaboration. Focus on delivering a concise solution.
#
# [Question] Solve for x: x^2 - 6x + 8 = 0.
# [Answer] To solve the quadratic equation \( x^2 - 6x + 8 = 0 \), we can use the factoring method.
#
# 1. **Identify the coefficients**: The equation is in the standard form \( ax^2 + bx + c = 0 \), where \( a = 1 \), \( b = -6 \), and \( c = 8 \).
#
# 2. **Factor the quadratic**: We need to find two numbers that multiply to \( c \) (which is 8) and add up to \( b \) (which is -6). The numbers that satisfy these conditions are -2 and -4, since:
#    - \( -2 \times -4 = 8 \)
#    - \( -2 + (-4) = -6 \)
#
# 3. **Write the factored form**: We can express the quadratic as:
#    \[
#    (x - 2)(x - 4) = 0
#    \]
#
# 4. **Set each factor to zero**: To find the values of \( x \), we set each factor equal to zero:
#    - \( x - 2 = 0 \)  →  \( x = 2 \)
#    - \( x - 4 = 0 \)  →  \( x = 4 \)
#
# 5. **List the solutions**: The solutions to the equation are \( x = 2 \) and \( x = 4 \).
#
# Since the task only requires one solution, we can choose \( x = 2 \) as the answer.
#
# [Answer]: 2 <ANS_START>2<ANS_END>
#
# [Question] A cyclist travels 30 kilometers in 1 hour, then 45 kilometers in 1.5 hours. What is the average speed for the entire trip?
# [Answer] To find the average speed for the entire trip, we need to follow these steps:
#
# 1. **Calculate the total distance traveled**:
#    - The cyclist travels 30 kilometers in the first part of the trip and 45 kilometers in the second part.
#    - Total distance = 30 km + 45 km = 75 km.
#
# 2. **Calculate the total time taken**:
#    - The time taken for the first part of the trip is 1 hour.
#    - The time taken for the second part of the trip is 1.5 hours.
#    - Total time = 1 hour + 1.5 hours = 2.5 hours.
#
# 3. **Calculate the average speed**:
#    - Average speed is defined as total distance divided by total time.
#    - Average speed = Total distance / Total time = 75 km / 2.5 hours.
#
# 4. **Perform the division**:
#    - 75 km ÷ 2.5 hours = 30 km/h.
#
# Thus, the average speed for the entire trip is 30 km/h.
#
# [Answer]: 30 <ANS_START>30<ANS_END>
#
# [Question] What is the probability of drawing 1 King and 1 Queen in succession from a standard deck of cards without replacement?
# [Answer] To find the probability of drawing 1 King and 1 Queen in succession from a standard deck of cards without replacement, we can follow these steps:
#
# 1. **Understand the Deck Composition**: A standard deck has 52 cards, which includes 4 Kings and 4 Queens.
#
# 2. **Calculate the Probability of Drawing a King First**:
#    - The probability of drawing a King on the first draw is the number of Kings divided by the total number of cards:
#    \[
#    P(\text{King first}) = \frac{4}{52} = \frac{1}{13}
#    \]
#
# 3. **Calculate the Probability of Drawing a Queen Second**:
#    - After drawing a King, there are now 51 cards left in the deck, including still 4 Queens.
#    - The probability of drawing a Queen after having drawn a King is:
#    \[
#    P(\text{Queen second | King first}) = \frac{4}{51}
#    \]
#
# 4. **Combine the Probabilities**:
#    - Since these two events are sequential and dependent (the first draw affects the second), we multiply the probabilities:
#    \[
#    P(\text{King first and Queen second}) = P(\text{King first}) \times P(\text{Queen second | King first}) = \frac{1}{13} \times \frac{4}{51} = \frac{4}{663}
#    \]
#
# 5. **Consider the Reverse Order (Queen first, King second)**:
#    - We also need to consider the scenario where a Queen is drawn first and then a King:
#    - The probability of drawing a Queen first is:
#    \[
#    P(\text{Queen first}) = \frac{4}{52} = \frac{1}{13}
#    \]
#    - The probability of drawing a King second after a Queen is:
#    \[
#    P(\text{King second | Queen first}) = \frac{4}{51}
#    \]
#    - Thus, the combined probability for this scenario is:
#    \[
#    P(\text{Queen first and King second}) = \frac{1}{13} \times \frac{4}{51} = \frac{4}{663}
#    \]
#
# 6. **Total Probability**:
#    - Since both scenarios (King first, Queen second and Queen first, King second) are mutually exclusive, we add the probabilities:
#    \[
#    P(\text{1 King and 1 Queen}) = P(\text{King first and Queen second}) + P(\text{Queen first and King second}) = \frac{4}{663} + \frac{4}{663} = \frac{8}{663}
#    \]
#
# 7. **Final Answer**:
#    - The total number of ways to draw 1 King and 1 Queen in succession from a standard deck of cards without replacement is 8.
#
# Thus, the final answer is:
# [Answer]: 8 <ANS_START>4<ANS_END>
#
# [Question] If cos(x) = 1/2, what are the possible values of x in degrees?
# [Answer] To solve the problem where cos(x) = 1/2, we need to determine the angles x in degrees that satisfy this equation.
#
# 1. **Understanding the cosine function**: The cosine function is periodic and has a range of values from -1 to 1. The specific value of 1/2 corresponds to certain angles on the unit circle.
#
# 2. **Identifying reference angles**: The cosine of an angle is equal to 1/2 at specific reference angles. The primary angle where cos(x) = 1/2 is 60 degrees.
#
# 3. **Considering the periodic nature of cosine**: The cosine function is positive in the first and fourth quadrants. Therefore, we need to find all angles in these quadrants that yield a cosine of 1/2.
#
# 4. **Calculating the angles**:
#    - The first angle is the reference angle: x = 60 degrees.
#    - The second angle in the fourth quadrant can be found by subtracting the reference angle from 360 degrees: x = 360 - 60 = 300 degrees.
#
# 5. **Listing all possible solutions**: The general solutions for cos(x) = 1/2 can be expressed as:
#    - x = 60 + 360n (for n being any integer)
#    - x = 300 + 360n (for n being any integer)
#
# 6. **Final answer**: The specific solutions in the range of 0 to 360 degrees are 60 degrees and 300 degrees.
#
# Thus, the possible values of x in degrees are 60 and 300. <ANS_START>60<ANS_END>
#
# [Question] What is the intersection of sets A = {1, 2, 3, 5} and B = {2, 3, 4, 6}?
# [Answer] To find the intersection of sets A and B, we need to identify the elements that are common to both sets.
#
# 1. **Identify the elements of each set**:
#    - Set A contains the elements: {1, 2, 3, 5}
#    - Set B contains the elements: {2, 3, 4, 6}
#
# 2. **List the elements of Set A**:
#    - 1
#    - 2
#    - 3
#    - 5
#
# 3. **List the elements of Set B**:
#    - 2
#    - 3
#    - 4
#    - 6
#
# 4. **Compare the elements of both sets**:
#    - Check each element of Set A against the elements of Set B:
#      - 1 is not in Set B.
#      - 2 is in Set B.
#      - 3 is in Set B.
#      - 5 is not in Set B.
#
# 5. **Identify the common elements**:
#    - The elements that are found in both Set A and Set B are: 2 and 3.
#
# 6. **Conclusion**:
#    - The intersection of sets A and B is {2, 3}.
#
# However, since the task specifies to provide a single answer, we can choose one of the common elements. The answer can be represented as either 2 or 3.
#
# For the purpose of this task, I will provide the first common element found.
#
# [Answer]: 2 <ANS_START>2<ANS_END>
#
#
# For each question present the reasoning followed by the correct answer.
#
# Final best prompt: You are a mathematics expert. Please solve the following mathematics problem directly and provide the answer clearly, without unnecessary elaboration. Focus on delivering a concise solution.
#
# [Question] Solve for x: x^2 - 6x + 8 = 0.
# [Answer] To solve the quadratic equation \( x^2 - 6x + 8 = 0 \), we can use the factoring method.
#
# 1. **Identify the coefficients**: The equation is in the standard form \( ax^2 + bx + c = 0 \), where \( a = 1 \), \( b = -6 \), and \( c = 8 \).
#
# 2. **Factor the quadratic**: We need to find two numbers that multiply to \( c \) (which is 8) and add up to \( b \) (which is -6). The numbers that satisfy these conditions are -2 and -4, since:
#    - \( -2 \times -4 = 8 \)
#    - \( -2 + (-4) = -6 \)
#
# 3. **Write the factored form**: We can express the quadratic as:
#    \[
#    (x - 2)(x - 4) = 0
#    \]
#
# 4. **Set each factor to zero**: To find the values of \( x \), we set each factor equal to zero:
#    - \( x - 2 = 0 \)  →  \( x = 2 \)
#    - \( x - 4 = 0 \)  →  \( x = 4 \)
#
# 5. **List the solutions**: The solutions to the equation are \( x = 2 \) and \( x = 4 \).
#
# Since the task only requires one solution, we can choose \( x = 2 \) as the answer.
#
# [Answer]: 2 <ANS_START>2<ANS_END>
#
# [Question] A cyclist travels 30 kilometers in 1 hour, then 45 kilometers in 1.5 hours. What is the average speed for the entire trip?
# [Answer] To find the average speed for the entire trip, we need to follow these steps:
#
# 1. **Calculate the total distance traveled**:
#    - The cyclist travels 30 kilometers in the first part of the trip and 45 kilometers in the second part.
#    - Total distance = 30 km + 45 km = 75 km.
#
# 2. **Calculate the total time taken**:
#    - The time taken for the first part of the trip is 1 hour.
#    - The time taken for the second part of the trip is 1.5 hours.
#    - Total time = 1 hour + 1.5 hours = 2.5 hours.
#
# 3. **Calculate the average speed**:
#    - Average speed is defined as total distance divided by total time.
#    - Average speed = Total distance / Total time = 75 km / 2.5 hours.
#
# 4. **Perform the division**:
#    - 75 km ÷ 2.5 hours = 30 km/h.
#
# Thus, the average speed for the entire trip is 30 km/h.
#
# [Answer]: 30 <ANS_START>30<ANS_END>
#
# [Question] What is the probability of drawing 1 King and 1 Queen in succession from a standard deck of cards without replacement?
# [Answer] To find the probability of drawing 1 King and 1 Queen in succession from a standard deck of cards without replacement, we can follow these steps:
#
# 1. **Understand the Deck Composition**: A standard deck has 52 cards, which includes 4 Kings and 4 Queens.
#
# 2. **Calculate the Probability of Drawing a King First**:
#    - The probability of drawing a King on the first draw is the number of Kings divided by the total number of cards:
#    \[
#    P(\text{King first}) = \frac{4}{52} = \frac{1}{13}
#    \]
#
# 3. **Calculate the Probability of Drawing a Queen Second**:
#    - After drawing a King, there are now 51 cards left in the deck, including still 4 Queens.
#    - The probability of drawing a Queen after having drawn a King is:
#    \[
#    P(\text{Queen second | King first}) = \frac{4}{51}
#    \]
#
# 4. **Combine the Probabilities**:
#    - Since these two events are sequential and dependent (the first draw affects the second), we multiply the probabilities:
#    \[
#    P(\text{King first and Queen second}) = P(\text{King first}) \times P(\text{Queen second | King first}) = \frac{1}{13} \times \frac{4}{51} = \frac{4}{663}
#    \]
#
# 5. **Consider the Reverse Order (Queen first, King second)**:
#    - We also need to consider the scenario where a Queen is drawn first and then a King:
#    - The probability of drawing a Queen first is:
#    \[
#    P(\text{Queen first}) = \frac{4}{52} = \frac{1}{13}
#    \]
#    - The probability of drawing a King second after a Queen is:
#    \[
#    P(\text{King second | Queen first}) = \frac{4}{51}
#    \]
#    - Thus, the combined probability for this scenario is:
#    \[
#    P(\text{Queen first and King second}) = \frac{1}{13} \times \frac{4}{51} = \frac{4}{663}
#    \]
#
# 6. **Total Probability**:
#    - Since both scenarios (King first, Queen second and Queen first, King second) are mutually exclusive, we add the probabilities:
#    \[
#    P(\text{1 King and 1 Queen}) = P(\text{King first and Queen second}) + P(\text{Queen first and King second}) = \frac{4}{663} + \frac{4}{663} = \frac{8}{663}
#    \]
#
# 7. **Final Answer**:
#    - The total number of ways to draw 1 King and 1 Queen in succession from a standard deck of cards without replacement is 8.
#
# Thus, the final answer is:
# [Answer]: 8 <ANS_START>4<ANS_END>
#
# [Question] If cos(x) = 1/2, what are the possible values of x in degrees?
# [Answer] To solve the problem where cos(x) = 1/2, we need to determine the angles x in degrees that satisfy this equation.
#
# 1. **Understanding the cosine function**: The cosine function is periodic and has a range of values from -1 to 1. The specific value of 1/2 corresponds to certain angles on the unit circle.
#
# 2. **Identifying reference angles**: The cosine of an angle is equal to 1/2 at specific reference angles. The primary angle where cos(x) = 1/2 is 60 degrees.
#
# 3. **Considering the periodic nature of cosine**: The cosine function is positive in the first and fourth quadrants. Therefore, we need to find all angles in these quadrants that yield a cosine of 1/2.
#
# 4. **Calculating the angles**:
#    - The first angle is the reference angle: x = 60 degrees.
#    - The second angle in the fourth quadrant can be found by subtracting the reference angle from 360 degrees: x = 360 - 60 = 300 degrees.
#
# 5. **Listing all possible solutions**: The general solutions for cos(x) = 1/2 can be expressed as:
#    - x = 60 + 360n (for n being any integer)
#    - x = 300 + 360n (for n being any integer)
#
# 6. **Final answer**: The specific solutions in the range of 0 to 360 degrees are 60 degrees and 300 degrees.
#
# Thus, the possible values of x in degrees are 60 and 300. <ANS_START>60<ANS_END>
#
# [Question] What is the intersection of sets A = {1, 2, 3, 5} and B = {2, 3, 4, 6}?
# [Answer] To find the intersection of sets A and B, we need to identify the elements that are common to both sets.
#
# 1. **Identify the elements of each set**:
#    - Set A contains the elements: {1, 2, 3, 5}
#    - Set B contains the elements: {2, 3, 4, 6}
#
# 2. **List the elements of Set A**:
#    - 1
#    - 2
#    - 3
#    - 5
#
# 3. **List the elements of Set B**:
#    - 2
#    - 3
#    - 4
#    - 6
#
# 4. **Compare the elements of both sets**:
#    - Check each element of Set A against the elements of Set B:
#      - 1 is not in Set B.
#      - 2 is in Set B.
#      - 3 is in Set B.
#      - 5 is not in Set B.
#
# 5. **Identify the common elements**:
#    - The elements that are found in both Set A and Set B are: 2 and 3.
#
# 6. **Conclusion**:
#    - The intersection of sets A and B is {2, 3}.
#
# However, since the task specifies to provide a single answer, we can choose one of the common elements. The answer can be represented as either 2 or 3.
#
# For the purpose of this task, I will provide the first common element found.
#
# [Answer]: 2 <ANS_START>2<ANS_END>
#
#
# For each question present the reasoning followed by the correct answer.
#
# Time taken to find best prompt: 493.6336860656738 sec
# Time taken to find best prompt: 493.6336860656738 sec
# Time taken to find best prompt: 493.6336860656738 sec
# Time taken to find best prompt: 493.6336860656738 sec

# %% [markdown]
# Output : Following Prompt and Expert Profile are generated

# %%
expert_profile
# Out:
# 'You are a mathematics expert with a strong foundation in various branches of mathematics, including algebra, geometry, calculus, and statistics. Your analytical skills and problem-solving abilities are exceptional, allowing you to tackle a wide range of mathematical problems with ease. You have a deep understanding of mathematical concepts and theories, which enables you to approach problems methodically and efficiently. Whether the problem involves complex equations, geometric figures, or statistical analysis, you can break it down into manageable steps and provide clear, logical solutions. Your experience in teaching and tutoring mathematics has honed your ability to explain concepts in a way that is accessible and understandable to others. You are well-equipped to solve the given mathematics problem, ensuring that your solution is not only correct but also clearly articulated for anyone seeking to understand the process.'

# %% [markdown]
# #### Scenario 3 : We have training data and also want in-context examples in final prompt

# %% [markdown]
# Load and save the dataset

# %%
if not os.path.exists("data"):
    os.mkdir("data")

dataset = load_dataset("openai/gsm8k", "main")
num_samples = 0
for dataset_type in ["train", "test"]:
    data_list = []
    for data in dataset[dataset_type]:
        data_list.append({"question": data["question"], "answer": data["answer"]})
        if (
            num_samples == 100 and dataset_type == "train"
        ):  # We sample only 100 train examples and use 25 out them for training randomly
            break
        num_samples += 1
    gsm8k_processor.dataset_to_jsonl(
        "data/" + dataset_type + ".jsonl", dataset=data_list
    )
# Out:
# Evaluating samples: 101it [00:00, 176657.51it/s]
# Evaluating samples: 1319it [00:00, 883469.65it/s]

# %%
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 7473
#     })
#     test: Dataset({
#         features: ['question', 'answer'],
#         num_rows: 1319
#     })
# })

# %% [markdown]
# Set the configurations

# %%
file_path = "configs/promptopt_config.yaml"
config_dict = {
    "task_description": "You are a mathematics expert. You will be given a mathematics problem which you need to solve",
    "base_instruction": "Lets think step by step.",
    "mutation_rounds": 2,
    "few_shot_count": 5,
    "generate_reasoning": True,
    "mutate_refine_iterations": 3,
    "seen_set_size": 20,
}
update_yaml_file(file_path, config_dict)

# %% [markdown]
# Create an object for calling prompt optimization and inference functionalities

# %%
gp = GluePromptOpt(
    promptopt_config_path,
    setup_config_path,
    dataset_jsonl=os.path.join("data", "train.jsonl"),
    data_processor=gsm8k_processor,
)

# %% [markdown]
# Call the optimization function

# %%
best_prompt, expert_profile = gp.get_best_prompt(
    use_examples=True,
    run_without_train_examples=False,
    generate_synthetic_examples=False,
)

# %% [markdown]
# Output : Following Prompt and Expert Profile are generated
