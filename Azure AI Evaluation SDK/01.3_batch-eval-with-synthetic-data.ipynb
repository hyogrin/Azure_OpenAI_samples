# %% [markdown]
# # Quality Evaluators with the Azure AI Evaluation SDK
# The following sample shows the basic way to evaluate a Generative AI application in your development environment with the Azure AI evaluation SDK.
#
# > ✨ ***Note*** <br>
# > Please check the reference document before you get started - https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/evaluate-sdk

# %% [markdown]
# ## 🔨 Current Support and Limitations (as of 2025-01-14)
# - Check the region support for the Azure AI Evaluation SDK. https://learn.microsoft.com/en-us/azure/ai-studio/concepts/evaluation-metrics-built-in?tabs=warning#region-support
#
# ### Region support for evaluations
# | Region              | Hate and Unfairness, Sexual, Violent, Self-Harm, XPIA, ECI (Text) | Groundedness (Text) | Protected Material (Text) | Hate and Unfairness, Sexual, Violent, Self-Harm, Protected Material (Image) |
# |---------------------|------------------------------------------------------------------|---------------------|----------------------------|----------------------------------------------------------------------------|
# | North Central US    | no                                                               | no                  | no                         | yes                                                                        |
# | East US 2           | yes                                                              | yes                 | yes                        | yes                                                                        |
# | Sweden Central      | yes                                                              | yes                 | yes                        | yes                                                                        |
# | US North Central    | yes                                                              | no                  | yes                        | yes                                                                        |
# | France Central      | yes                                                              | yes                 | yes                        | yes                                                                        |
# | Switzerland West    | yes                                                              | no                  | no                         | yes                                                                        |
#
# ### Region support for adversarial simulation
# | Region            | Adversarial Simulation (Text) | Adversarial Simulation (Image) |
# |-------------------|-------------------------------|---------------------------------|
# | UK South          | yes                           | no                              |
# | East US 2         | yes                           | yes                             |
# | Sweden Central    | yes                           | yes                             |
# | US North Central  | yes                           | yes                             |
# | France Central    | yes                           | no                              |

# %% [markdown]
# ## ✔️ Pricing and billing
# - Effective 1/14/2025, Azure AI Safety Evaluations will no longer be free in public preview. It will be billed based on consumption as following:
#
# | Service Name              | Safety Evaluations       | Price Per 1K Tokens (USD) |
# |---------------------------|--------------------------|---------------------------|
# | Azure Machine Learning    | Input pricing for 3P     | $0.02                     |
# | Azure Machine Learning    | Output pricing for 3P    | $0.06                     |
# | Azure Machine Learning    | Input pricing for 1P     | $0.012                    |
# | Azure Machine Learning    | Output pricing for 1P    | $0.012                    |

# %%
import pandas as pd
import os
import json

from pprint import pprint
from azure.ai.evaluation import evaluate
from azure.ai.evaluation import RelevanceEvaluator
from azure.ai.evaluation import GroundednessEvaluator, GroundednessProEvaluator
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    Evaluation,
    Dataset,
    EvaluatorConfiguration,
    ConnectionType,
    EvaluationSchedule,
    RecurrenceTrigger,
    ApplicationInsightsConfiguration
)
import pathlib

from azure.ai.evaluation import evaluate
from azure.ai.evaluation import (
    ContentSafetyEvaluator,
    RelevanceEvaluator,
    CoherenceEvaluator,
    GroundednessEvaluator,
    FluencyEvaluator,
    SimilarityEvaluator,
    F1ScoreEvaluator,
    RetrievalEvaluator
)

from azure.ai.ml import MLClient



load_dotenv()
# Out:
# True

# %%
credential = DefaultAzureCredential()

azure_ai_project_conn_str = os.environ.get("AZURE_AI_PROJECT_CONN_STR")
subscription_id = azure_ai_project_conn_str.split(";")[1]
resource_group_name = azure_ai_project_conn_str.split(";")[2]
project_name = azure_ai_project_conn_str.split(";")[3]

azure_ai_project_dict = {
    "subscription_id": subscription_id,
    "resource_group_name": resource_group_name,
    "project_name": project_name,
}

azure_ai_project_client = AIProjectClient.from_connection_string(
    credential=DefaultAzureCredential(),
    conn_str=azure_ai_project_conn_str
)


model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "api_key": os.environ.get("AZURE_OPENAI_API_KEY"),
    "azure_deployment": os.environ.get("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"),
    "api_version": os.environ.get("AZURE_OPENAI_API_VERSION"),
    "type": "azure_openai",
}

# %% [markdown]
# ## 🚀 Generate synthetic dataset with Azure OpenAI
# - Use your models to generate custom textual utterances for your purpose in your target language. These utterances serve as a seed for the evaluation creation. By adjusting your prompts, you can produce text tailored to your domain (such as call center Q&A for a tech brand).

# %%
from openai import AzureOpenAI


aoai_api_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
aoai_api_key = os.getenv("AZURE_OPENAI_API_KEY")
aoai_api_version = os.getenv("AZURE_OPENAI_API_VERSION")
aoai_deployment_name = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")

try:
    client = AzureOpenAI(
        azure_endpoint = aoai_api_endpoint,
        api_key        = aoai_api_key,
        api_version    = aoai_api_version,
    )

    print("=== Initialized AzuureOpenAI client ===")
    print(f"AZURE_OPENAI_ENDPOINT={aoai_api_endpoint}")
    print(f"AZURE_OPENAI_API_VERSION={aoai_api_version}")
    print(f"AZURE_OPENAI_DEPLOYMENT_NAME={aoai_deployment_name}")
        
except (ValueError, TypeError) as e:
    print(e)
# Out:
# === Initialized AzuureOpenAI client ===
# AZURE_OPENAI_ENDPOINT=https://aoai-services1.openai.azure.com/
# AZURE_OPENAI_API_VERSION=2024-12-01-preview
# AZURE_OPENAI_DEPLOYMENT_NAME=gpt-4o-mini

# %%
NUM_SAMPLES = 20

LANGUAGE = "English"

topic = f"""
Contoso Electronics call center QnA related expected spoken utterances for {LANGUAGE} languages. create {NUM_SAMPLES} lines of jsonl of the topic related text.
"""

example = """
Here is examples of the expected format:
{"query":"How do you create a run?","context":"AML API only","response":"To create a run using the Azure Machine Learning API, you first need to create an Experiment. Once you have an experiment, you can create a Run object that is associated with that experiment. Here is some Python code that demonstrates this process:\\n\\n```\\nfrom azureml.core import Experiment, Run\\nfrom azureml.core.workspace import Workspace\\n\\n# Define workspace and experiment\\nws = Workspace.from_config()\\nexp = Experiment(workspace=ws, name='my_experiment')\\n\\n# Create a new run\\nrun = exp.start_logging()\\n```\\n\\nIn this code, the `from_config()` method reads the configuration file that you created when you set up your Azure Machine Learning workspace. The `Experiment` constructor creates an Experiment object that is associated with your workspace, and the `start_logging()` method creates a new Run object that is associated with the Experiment. Now you can use the `run` object to log metrics, upload files, and track other information related to your machine learning experiment.","ground_truth":"Paris is the capital of France."}
{"query":"How do you log a model?","context":"Logging can be done using any OSS Sdk","response":"There are a few ways to log models in Azure Machine Learning. \\n\\nOne way is to use the `register_model()` method of the `Run` object. The `register_model()` method logs a model file in the Azure Machine Learning service workspace and makes it available for deployment. Here's an example:\\n\\n```python\\nfrom azureml.core import Model\\n\\nmodel_path = './outputs/my_model.pkl'\\nmodel = Model.register(workspace=ws, model_path=model_path, model_name='my_model')\\n```\\n\\nThis code registers the model file located at `model_path` to the Azure Machine Learning service workspace with the name `my_model`. \\n\\nAnother way to log a model is to save it as an output of a `Run`. If your model generation code is part of a script or Jupyter notebook that runs as an Azure Machine Learning experiment, you can save the model file as an output of the `Run` object. Here's an example:\\n\\n```python\\nfrom sklearn.linear_model import LogisticRegression\\nfrom azureml.core.run import Run\\n\\n# Initialize a run object\\nrun = Run.get_context()\\n\\n# Train your model\\nX_train, y_train = ...\\nlog_reg = LogisticRegression().fit(X_train, y_train)\\n\\n# Save the model to the Run object's outputs directory\\nmodel_path = 'outputs/model.pkl'\\njoblib.dump(value=log_reg, filename=model_path)\\n\\n# Log the model as a run artifact\\nrun.upload_file(name=model_path, path_or_stream=model_path)\\n```\\n\\nIn this code, `Run.get_context()` retrieves the current run context object, which you can use to track metadata and metrics for the run. After training your model, you can use `joblib.dump()` to save the model to a file, and then log the file as an artifact of the run using `run.upload_file()`.","ground_truth":"Paris is the capital of France."}
{"query":"What is the capital of France?","context":"France is in Europe","response":"Paris is the capital of France.","ground_truth":"Paris is the capital of France."}
"""

system_message = """
Generate plain text sentences of #topic# related text to improve the recognition of domain-specific words and phrases.
Domain-specific words can be uncommon or made-up words, but their pronunciation must be straightforward to be recognized. 
Use text data that's close to the expected spoken utterances. The nummber of utterances per line should be 1. 
jsonl format is required. use 'no' as number, 'query' as string, 'context' as string, 'response' as string, and 'ground_truth' as string.
only include the lines as the result. Do not include ```jsonl, ``` and blank line in the result. 

"""

user_message = f"""
#topic#: {topic}
Example: {example}
"""

# Simple API Call
response = client.chat.completions.create(
    model=aoai_deployment_name,
    messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message},
    ],
    temperature=0.8,
    top_p=0.1
)

content = response.choices[0].message.content
print(content)
print("Usage Information:")
#print(f"Cached Tokens: {response.usage.prompt_tokens_details.cached_tokens}") #only o1 models support this
print(f"Completion Tokens: {response.usage.completion_tokens}")
print(f"Prompt Tokens: {response.usage.prompt_tokens}")
print(f"Total Tokens: {response.usage.total_tokens}")
# Out:
# {"query":"What are the latest products from Contoso Electronics?","context":"Product catalog inquiry","response":"The latest products from Contoso Electronics include the Contoso Smart Speaker, Contoso Ultra HD TV, and the Contoso Wireless Earbuds.","ground_truth":"Paris is the capital of France."}
# {"query":"How can I track my order with Contoso?","context":"Order tracking process","response":"To track your order with Contoso, visit our website and enter your order number in the tracking section.","ground_truth":"Paris is the capital of France."}
# {"query":"What warranty do Contoso products come with?","context":"Warranty information","response":"Contoso products typically come with a one-year warranty that covers manufacturing defects.","ground_truth":"Paris is the capital of France."}
# {"query":"Can I return a product to Contoso?","context":"Return policy","response":"Yes, you can return a product to Contoso within 30 days of purchase if it is in its original condition.","ground_truth":"Paris is the capital of France."}
# {"query":"How do I contact Contoso customer support?","context":"Customer support contact","response":"You can contact Contoso customer support by calling our hotline or using the live chat feature on our website.","ground_truth":"Paris is the capital of France."}
# {"query":"What payment methods does Contoso accept?","context":"Payment options","response":"Contoso accepts various payment methods including credit cards, PayPal, and bank transfers.","ground_truth":"Paris is the capital of France."}
# {"query":"Are there any discounts available at Contoso?","context":"Discount inquiries","response":"Yes, Contoso often has seasonal discounts and promotions available on select products.","ground_truth":"Paris is the capital of France."}
# {"query":"What is the return process for Contoso products?","context":"Return process details","response":"To return a product, fill out the return form included with your order and send it back to us with the item.","ground_truth":"Paris is the capital of France."}
# {"query":"How do I set up my Contoso Smart Speaker?","context":"Product setup instructions","response":"To set up your Contoso Smart Speaker, download the Contoso app and follow the on-screen instructions to connect it to your Wi-Fi.","ground_truth":"Paris is the capital of France."}
# {"query":"What features does the Contoso Ultra HD TV have?","context":"Product features inquiry","response":"The Contoso Ultra HD TV features 4K resolution, smart connectivity, and voice control capabilities.","ground_truth":"Paris is the capital of France."}
# {"query":"Can I upgrade my Contoso product?","context":"Upgrade options","response":"Yes, you can upgrade your Contoso product by purchasing the latest model or software updates available on our website.","ground_truth":"Paris is the capital of France."}
# {"query":"What is the shipping policy for Contoso?","context":"Shipping information","response":"Contoso offers free shipping on orders over $50 and typically ships within 3-5 business days.","ground_truth":"Paris is the capital of France."}
# {"query":"How do I reset my Contoso device?","context":"Device reset instructions","response":"To reset your Contoso device, locate the reset button and hold it for 10 seconds until the device restarts.","ground_truth":"Paris is the capital of France."}
# {"query":"What is the battery life of Contoso Wireless Earbuds?","context":"Product specifications","response":"The Contoso Wireless Earbuds have a battery life of up to 8 hours on a single charge, with an additional 24 hours from the charging case.","ground_truth":"Paris is the capital of France."}
# {"query":"Where can I find Contoso product manuals?","context":"Manuals and documentation","response":"You can find Contoso product manuals on our website under the support section for each product.","ground_truth":"Paris is the capital of France."}
# {"query":"Does Contoso offer international shipping?","context":"Shipping options","response":"Yes, Contoso offers international shipping to select countries. Please check our website for more details.","ground_truth":"Paris is the capital of France."}
# {"query":"What should I do if my Contoso product is defective?","context":"Defective product process","response":"If your Contoso product is defective, please contact customer support for assistance with a replacement or repair.","ground_truth":"Paris is the capital of France."}
# {"query":"How can I leave feedback for Contoso?","context":"Feedback process","response":"You can leave feedback for Contoso by filling out the feedback form on our website or through our customer support channels.","ground_truth":"Paris is the capital of France."}
# {"query":"What is the Contoso loyalty program?","context":"Loyalty program details","response":"The Contoso loyalty program rewards customers with points for every purchase, which can be redeemed for discounts on future orders.","ground_truth":"Paris is the capital of France."}
# Usage Information:
# Completion Tokens: 1026
# Prompt Tokens: 898
# Total Tokens: 1924

# %%
synthetic_text_file = "data/sythetic_evaluation_data.jsonl"
with open(synthetic_text_file, 'w', encoding='utf-8') as f:
    for line in content.split('\n'):
        if line.strip():  # Check if the line is not empty
            f.write(line + '\n')

# %store synthetic_text_file
# Out:
# Stored 'synthetic_text_file' (str)

# %% [markdown]
# ## 🚀 Run Evaluators in Azure Cloud (azure.ai.evaluation.evaluate)

# %%
#current_dir = os.path.dirname(__file__)
current_dir = os.path.dirname(os.getcwd())
input_path = os.path.join(
    current_dir, "Azure AI Evaluation SDK/data/sythetic_evaluation_data.jsonl"
)
output_path = os.path.join(
    current_dir, "Azure AI Evaluation SDK/data/informative_data_results_test.json"
)

# https://learn.microsoft.com/en-us/azure/ai-studio/how-to/develop/flow-evaluate-sdk
retrieval_evaluator = RetrievalEvaluator(model_config)
fluency_evaluator = FluencyEvaluator(model_config)
groundedness_evaluator = GroundednessEvaluator(model_config)
relevance_evaluator = RelevanceEvaluator(model_config)
coherence_evaluator = CoherenceEvaluator(model_config)
similarity_evaluator = SimilarityEvaluator(model_config)

column_mapping = {
    "query": "${data.query}",
    "ground_truth": "${data.ground_truth}",
    "response": "${data.response}",
    "context": "${data.context}",
}

# %%
import time
from datetime import datetime
result = evaluate(
    evaluation_name=f"evaluation_cloud_{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}",
    data=synthetic_text_file,
    evaluators={
        "retrieval": retrieval_evaluator,
        "fluency": fluency_evaluator,
        "groundedness": groundedness_evaluator,
        "relevance": relevance_evaluator,
        "coherence": coherence_evaluator,
        "similarity": similarity_evaluator
    },
    evaluator_config={
        "retrieval": {"column_mapping": column_mapping},
        "relevance": {"column_mapping": column_mapping},
        "similarity": {"column_mapping": column_mapping},
        "groundedness": {"column_mapping": column_mapping},
        "coherence": {"column_mapping": column_mapping},
        "similarity": {"column_mapping": column_mapping},
    },
    azure_ai_project=azure_ai_project_dict,
    output_path=output_path,
)
# Out:
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# Starting prompt flow service...
# [2025-02-26 10:39:56 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-02-26 10:39:56 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-02-26 10:39:56 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-26 10:39:56 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_4dr65pv0_20250226_103942_545509, log path: /home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_4dr65pv0_20250226_103942_545509/logs.txt
# [2025-02-26 10:39:56 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-02-26 10:39:56 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025-02-26 10:39:56 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-26 10:39:56 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gtzjki11_20250226_103942_543014, log path: /home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gtzjki11_20250226_103942_543014/logs.txt
# [2025-02-26 10:39:57 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-02-26 10:39:57 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-02-26 10:39:57 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-02-26 10:39:57 +0000][promptflow][WARNING] - Prompt flow service is not healthy. Kindly reminder: If you have previously upgraded the prompt flow package , please double-confirm that you have run 'pf service stop' to stop the prompt flowservice before proceeding with the upgrade. Otherwise, you may encounter unexpected environmental issues or inconsistencies between the version of running prompt flow service and the local prompt flow version. Alternatively, you can use the 'pf upgrade' command to proceed with the upgrade process for the prompt flow package.
# [2025-02-26 10:39:57 +0000][promptflow][WARNING] - Prompt flow service is not healthy, please check the logs for more details; traces might not be exported correctly.
# [2025
/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gtzjki11_20250226_103942_543014"
#
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.28 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 17 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 0.64 seconds.
# 2025-02-26 10:40:03 +0000  220730 execution.bulk     INFO     Finished 18 / 19 lines.
# 2025-02-26 10:40:03 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 0.33 seconds.
# 2025-02-26 10:39:57 +0000  220730 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 1 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 1.84 seconds. Estimated time for incomplete lines: 33.12 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 2 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.99 seconds. Estimated time for incomplete lines: 16.83 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 3 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.71 seconds. Estimated time for incomplete lines: 11.36 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 4 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.57 seconds. Estimated time for incomplete lines: 8.55 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 5 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.48 seconds. Estimated time for incomplete lines: 6.72 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 6 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.41 seconds. Estimated time for incomplete lines: 5.33 seconds.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Finished 7 / 19 lines.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.39 seconds. Estimated time for incomplete lines: 4.68 seconds.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Finished 8 / 19 lines.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.43 seconds. Estimated time for incomplete lines: 4.73 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 9 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.39 seconds. Estimated time for incomplete lines: 3.9 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 10 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.37 seconds. Estimated time for incomplete lines: 3.33 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 11 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.36 seconds. Estimated time for incomplete lines: 2.88 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 12 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 2.31 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 13 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 1.98 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 14 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 1.6 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 15 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.31 seconds. Estimated time for incomplete lines: 1.24 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 16 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.29 seconds. Estimated time for incomplete lines: 0.87 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 17 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.28 seconds. Estimated time for incomplete lines: 0.56 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 18 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.27 seconds. Estimated time for incomplete lines: 0.27 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.28 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_n9bk96h9_20250226_103942_549735"
# Run status: "Completed"
# Start time: "2025-02-26 10:39:42.542946+00:00"
# Duration: "0:00:21.012121"
# Output path: "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_n9bk96h9_20250226_103942_549735"
#
# 2025-02-26 10:40:04 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:04 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.35 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-26 10:39:57 +0000  220730 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 1 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 2.0 seconds. Estimated time for incomplete lines: 36.0 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 2 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 1.02 seconds. Estimated time for incomplete lines: 17.34 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 3 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.7 seconds. Estimated time for incomplete lines: 11.2 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 4 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.53 seconds. Estimated time for incomplete lines: 7.95 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 5 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.45 seconds. Estimated time for incomplete lines: 6.3 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 6 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.41 seconds. Estimated time for incomplete lines: 5.33 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 7 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.36 seconds. Estimated time for incomplete lines: 4.32 seconds.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Finished 8 / 19 lines.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.41 seconds. Estimated time for incomplete lines: 4.51 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 9 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.4 seconds. Estimated time for incomplete lines: 4.0 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 10 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.37 seconds. Estimated time for incomplete lines: 3.33 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 11 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.37 seconds. Estimated time for incomplete lines: 2.96 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 12 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.36 seconds. Estimated time for incomplete lines: 2.52 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 13 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.34 seconds. Estimated time for incomplete lines: 2.04 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 14 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.34 seconds. Estimated time for incomplete lines: 1.7 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 15 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.34 seconds. Estimated time for incomplete lines: 1.36 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 16 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 0.96 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 17 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 0.64 seconds.
# 2025-02-26 10:40:03 +0000  220730 execution.bulk     INFO     Finished 18 / 19 lines.
# 2025-02-26 10:40:03 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 0.33 seconds.
# 2025-02-26 10:40:04 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:04 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.35 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_o36mabs9_20250226_103942_546953"
# Run status: "Completed"
# Start time: "2025-02-26 10:39:42.535625+00:00"
# Duration: "0:00:21.946624"
# Output path: "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_o36mabs9_20250226_103942_546953"
#
# 2025-02-26 10:40:05 +0000  220730 execution.bulk     INFO     Finished 18 / 19 lines.
# 2025-02-26 10:40:05 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.43 seconds. Estimated time for incomplete lines: 0.43 seconds.
# 2025-02-26 10:40:07 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:07 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.54 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-26 10:39:57 +0000  220730 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 1 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 2.03 seconds. Estimated time for incomplete lines: 36.54 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 2 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 1.05 seconds. Estimated time for incomplete lines: 17.85 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 3 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.74 seconds. Estimated time for incomplete lines: 11.84 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 6 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.38 seconds. Estimated time for incomplete lines: 4.94 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 7 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 3.96 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 8 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.3 seconds. Estimated time for incomplete lines: 3.3 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 9 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.27 seconds. Estimated time for incomplete lines: 2.7 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 10 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.24 seconds. Estimated time for incomplete lines: 2.16 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 11 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.36 seconds. Estimated time for incomplete lines: 2.88 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 12 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.34 seconds. Estimated time for incomplete lines: 2.38 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 13 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 1.92 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 14 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 1.65 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 15 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.31 seconds. Estimated time for incomplete lines: 1.24 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 16 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.29 seconds. Estimated time for incomplete lines: 0.87 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 17 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.28 seconds. Estimated time for incomplete lines: 0.56 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 18 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.27 seconds. Estimated time for incomplete lines: 0.27 seconds.
# 2025-02-26 10:40:07 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:07 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.54 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_omnxx_74_20250226_103942_550239"
# Run status: "Completed"
# Start time: "2025-02-26 10:39:42.542569+00:00"
# Duration: "0:00:25.979790"
# Output path: "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_omnxx_74_20250226_103942_550239"
#
# 2025-02-26 10:40:10 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:10 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.67 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-26 10:39:57 +0000  220730 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 1 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 1.76 seconds. Estimated time for incomplete lines: 31.68 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 2 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.89 seconds. Estimated time for incomplete lines: 15.13 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 3 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.65 seconds. Estimated time for incomplete lines: 10.4 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 4 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.5 seconds. Estimated time for incomplete lines: 7.5 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 5 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.41 seconds. Estimated time for incomplete lines: 5.74 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 6 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.36 seconds. Estimated time for incomplete lines: 4.68 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 7 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 3.96 seconds.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Finished 8 / 19 lines.
# 2025-02-26 10:39:59 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.29 seconds. Estimated time for incomplete lines: 3.19 seconds.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Finished 9 / 19 lines.
# 2025-02-26 10:40:00 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.37 seconds. Estimated time for incomplete lines: 3.7 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 10 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.36 seconds. Estimated time for incomplete lines: 3.24 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 11 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 2.64 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 12 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.33 seconds. Estimated time for incomplete lines: 2.31 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 13 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 1.92 seconds.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Finished 14 / 19 lines.
# 2025-02-26 10:40:01 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.3 seconds. Estimated time for incomplete lines: 1.5 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 15 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.32 seconds. Estimated time for incomplete lines: 1.28 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 16 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.31 seconds. Estimated time for incomplete lines: 0.93 seconds.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Finished 17 / 19 lines.
# 2025-02-26 10:40:02 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.29 seconds. Estimated time for incomplete lines: 0.58 seconds.
# 2025-02-26 10:40:05 +0000  220730 execution.bulk     INFO     Finished 18 / 19 lines.
# 2025-02-26 10:40:05 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.43 seconds. Estimated time for incomplete lines: 0.43 seconds.
# 2025-02-26 10:40:10 +0000  220730 execution.bulk     INFO     Finished 19 / 19 lines.
# 2025-02-26 10:40:10 +0000  220730 execution.bulk     INFO     Average execution time for completed lines: 0.67 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_zsvgua_w_20250226_103942_541957"
# Run status: "Completed"
# Start time: "2025-02-26 10:39:42.535982+00:00"
# Duration: "0:00:28.036371"
# Output path: "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_zsvgua_w_20250226_103942_541957"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "retrieval": {
#         "status": "Completed",
#         "duration": "0:00:25.979790",
#         "completed_lines": 19,
#         "failed_lines": 0,
#         "log_path": "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_omnxx_74_20250226_103942_550239"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:28.036371",
#         "completed_lines": 19,
#         "failed_lines": 0,
#         "log_path": "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_zsvgua_w_20250226_103942_541957"
#     },
#     "groundedness": {
#         "status": "Completed",
#         "duration": "0:00:21.946624",
#         "completed_lines": 19,
#         "failed_lines": 0,
#         "log_path": "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_o36mabs9_20250226_103942_546953"
#     },
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:20.190960",
#         "completed_lines": 19,
#         "failed_lines": 0,
#         "log_path": "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_gtzjki11_20250226_103942_543014"
#     },
#     "coherence": {
#         "status": "Completed",
#         "duration": "0:00:21.012121",
#         "completed_lines": 19,
#         "failed_lines": 0,
#         "log_path": "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_n9bk96h9_20250226_103942_549735"
#     },
#     "similarity": {
#         "status": "Completed",
#         "duration": "0:00:15.876840",
#         "completed_lines": 19,
#         "failed_lines": 0,
#         "log_path": "/home/azureuser/.promptflow/.runs/azure_ai_evaluation_evaluators_similarity_similarity_asyncsimilarityevaluator_4dr65pv0_20250226_103942_545509"
#     }
# }
#
# ====================================================
#
# Evaluation results saved to "/afh/code/Azure_OpenAI_samples/Azure AI Evaluation SDK/data/informative_data_results_test.json".
