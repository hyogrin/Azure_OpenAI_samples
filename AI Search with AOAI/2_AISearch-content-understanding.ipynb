# %% [markdown]
# # AI Search with Azure Content Understanding
# This document illustrates an example workflow for how to leverage the Azure AI Content Understanding API to enhance the quality of document search.
# > ✨ ***Note*** <br>
# The sample will demonstrate the following steps:
# 1. Extract the layout and content of a document using Azure AI Document Intelligence.
# 2. For each figure in the document, extract its content with a custom analyzer using Azure AI Content Understanding, and insert it into the corresponding location in the document content.
# 2. Chunk and embed the document content with LangChain and Azure OpenAI, and index them with Azure Search to generate an Azure Search index.
# 3. Utilize an OpenAI chat model to search through content in the document with a natural language query.
#
# ## more sample
# https://github.com/Azure-Samples/azure-ai-content-understanding-python
#
# ## Prerequisites
# Configure a Python virtual environment for 3.10 or later:
#  1. open the Command Palette (Ctrl+Shift+P).
#  1. Search for Python: Create Environment.
#  1. select Venv / Conda and choose where to create the new environment.
#  1. Select the Python interpreter version. Create with version 3.10 or later.
#
# For a dependency installation, run the code below to install the packages required to run it.
#
# ```bash
# pip install -r requirements.txt
# ```
#
# ## Set up your environment
# Git clone the repository to your local machine.
#
# ```bash
# git clone https://github.com/hyogrin/Azure_OpenAI_samples.git
# ```
#
# Create an .env file based on the .env-sample file. Copy the new .env file to the folder containing your notebook and update the variables.

# %% [markdown]
# ## Load environment variables

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

# Load and validate Azure AI Services configs
AZURE_AI_SERVICE_ENDPOINT = os.getenv("AZURE_AI_SERVICE_ENDPOINT")
AZURE_AI_SERVICE_API_VERSION = os.getenv("AZURE_AI_SERVICE_API_VERSION") or "2024-12-01-preview"
AZURE_DOCUMENT_INTELLIGENCE_API_VERSION = os.getenv("AZURE_DOCUMENT_INTELLIGENCE_API_VERSION") or "2024-11-30"

# Load and validate Azure OpenAI configs
AZURE_OPENAI_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT")
AZURE_OPENAI_API_KEY = os.getenv("AZURE_OPENAI_API_KEY")
AZURE_OPENAI_CHAT_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")
AZURE_OPENAI_CHAT_API_VERSION = os.getenv("AZURE_OPENAI_CHAT_API_VERSION") or "2024-08-01-preview"
AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME")
AZURE_OPENAI_EMBEDDING_API_VERSION = os.getenv("AZURE_OPENAI_EMBEDDING_API_VERSION") or "2023-05-15"

# Load and validate Azure Search Services configs
AZURE_SEARCH_ENDPOINT = os.getenv("AZURE_SEARCH_ENDPOINT")
AZURE_SEARCH_API_KEY = os.getenv("AZURE_SEARCH_API_KEY")
AZURE_SEARCH_INDEX_NAME = "sample-index-visual-doc"

# %% [markdown]
# ## File to analyze

# %%
from pathlib import Path

# Get the path to the file that will be analyzed
# Sample report source: https://www.imf.org/en/Publications/CR/Issues/2024/07/18/United-States-2024-Article-IV-Consultation-Press-Release-Staff-Report-and-Statement-by-the-552100
#file = Path("data/sample_report.pdf")
#file = Path("data/2024-Coupang-Impact-Report.pdf")
#file = Path("data/2024_edu_curriculum_info.pdf")
#file = Path("data/JIHAKSA_science_4-1.pdf")
file = Path("data/smu_ojt_2024.pdf")

# %% [markdown]
# ## Create custom analyzer using chart and diagram understanding template

# %%
import json
import sys
import uuid

# Add the parent directory to the path to use shared modules
parent_dir = Path(Path.cwd()).parent
sys.path.append(str(parent_dir))
from python.content_understanding_client import AzureContentUnderstandingClient

from azure.identity import DefaultAzureCredential, get_bearer_token_provider
credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

# Get path to sample template
ANALYZER_TEMPLATE_PATH = "analyzer_templates/image_chart_diagram_understanding.json"

# Create analyzer
ANALYZER_ID = "content-understanding-search-sample-" + str(uuid.uuid4())
content_understanding_client = AzureContentUnderstandingClient(
    endpoint=AZURE_AI_SERVICE_ENDPOINT,
    api_version=AZURE_AI_SERVICE_API_VERSION,
    token_provider=token_provider,
    x_ms_useragent="azure-ai-content-understanding-python/search_with_visusal_document", # This header is used for sample usage telemetry, please comment out this line if you want to opt out.
)

try:
    response = content_understanding_client.begin_create_analyzer(ANALYZER_ID, analyzer_template_path=ANALYZER_TEMPLATE_PATH)
    result = content_understanding_client.poll_result(response)
    print(f'Analyzer details for {result["result"]["analyzerId"]}:')
    print(json.dumps(result, indent=2))
except Exception as e:
    print(e)
    print("Error in creating analyzer. Please double-check your analysis settings.\nIf there is a conflict, you can delete the analyzer and then recreate it, or move to the next cell and use the existing analyzer.")
# Out:
# Analyzer details for content-understanding-search-sample-ffafb5c7-0686-472d-b900-8ea8bdf71139:
# {
#   "id": "d1f1cfe8-103e-436f-bc48-07a518fb81f8",
#   "status": "Succeeded",
#   "result": {
#     "analyzerId": "content-understanding-search-sample-ffafb5c7-0686-472d-b900-8ea8bdf71139",
#     "description": "Extract detailed structured information from charts and diagrams.",
#     "createdAt": "2025-01-17T00:17:23Z",
#     "lastModifiedAt": "2025-01-17T00:17:23Z",
#     "config": {
#       "returnDetails": false
#     },
#     "fieldSchema": {
#       "name": "ChartsAndDiagrams",
#       "fields": {
#         "Title": {
#           "type": "string",
#           "description": "Verbatim title of the chart."
#         },
#         "ChartType": {
#           "type": "string",
#           "description": "The type of chart.",
#           "enum": [
#             "area",
#             "bar",
#             "box",
#             "bubble",
#             "candlestick",
#             "funnel",
#             "heatmap",
#             "histogram",
#             "line",
#             "pie",
#             "radar",
#             "rings",
#             "rose",
#             "treemap"
#           ],
#           "enumDescriptions": {
#             "histogram": "Continuous values on the x-axis, which distinguishes it from bar.",
#             "rose": "In contrast to pie charts, the sectors are of equal angles and differ in how far each sector extends from the center of the circle."
#           }
#         },
#         "TopicKeywords": {
#           "type": "array",
#           "description": "Relevant topics associated with the chart, used for tagging.",
#           "items": {
#             "type": "string",
#             "examples": [
#               "Business and finance",
#               "Arts and culture",
#               "Education and academics"
#             ]
#           }
#         },
#         "DetailedDescription": {
#           "type": "string",
#           "description": "Detailed description of the chart or diagram, not leaving out any key information. Include numbers, trends, and other details."
#         },
#         "Summary": {
#           "type": "string",
#           "description": "Detailed summary of the chart, including highlights and takeaways."
#         },
#         "MarkdownDataTable": {
#           "type": "string",
#           "description": "Underlying data of the chart in tabular markdown format. Give markdown output with valid syntax and accurate numbers, and fill any uncertain values with empty cells. If not applicable, output an empty string."
#         },
#         "AxisTitles": {
#           "type": "object",
#           "description": "Titles of the x and y axes.",
#           "properties": {
#             "xAxisTitle": {
#               "type": "string"
#             },
#             "yAxisTitle": {
#               "type": "string"
#             }
#           }
#         },
#         "FootnotesAndAnnotations": {
#           "type": "string",
#           "description": "All footnotes and textual annotations in the chart or diagram."
#         }
#       }
#     },
#     "warnings": [],
#     "status": "ready",
#     "scenario": "image"
#   }
# }

# %% [markdown]
# ## 🧪 Analyze document layout and compose with figure descriptions

# %%
from azure.ai.documentintelligence import DocumentIntelligenceClient
from azure.ai.documentintelligence.models import AnalyzeResult
from azure.ai.documentintelligence.models import AnalyzeDocumentRequest
import fitz
from PIL import Image

# Define helper functions for document-figure composition
def insert_figure_contents(md_content, figure_contents, span_offsets):
    """
    Inserts the figure content for each of the provided figures in figure_contents
    before the span offset of that figure in the given markdown content.

    Args:
    - md_content (str): The original markdown content.
    - figure_contents (list[str]): The contents of each figure to insert.
    - span_offsets (list[int]): The span offsets of each figure in order. These should be sorted and strictly increasing.

    Returns:
    - str: The modified markdown content with the the figure contents prepended to each figure's span.
    """
    # NOTE: In this notebook, we only alter the Markdown content returned by the Document Intelligence API,
    # and not the per-element spans in the API response. Thus, after figure content insertion, these per-element spans will be inaccurate.
    # This may impact use cases like citation page number calculation.
    # Additional code may be needed to correct the spans or otherwise infer the page numbers for each citation.
    # The main purpose of the notebook is to show the feasibility of using Content Understanding with Azure Search for RAG chat applications.

    # Validate span_offsets are sorted and strictly increasing
    if span_offsets != sorted(span_offsets) or not all([o < span_offsets[i + 1] for i, o in enumerate(span_offsets) if i < len(span_offsets) - 1]):
        raise ValueError("span_offsets should be sorted and strictly increasing.")

    # Split the content based on the provided spans
    parts = []
    preamble = None
    for i, offset in enumerate(span_offsets):
        if i == 0 and offset > 0:
            preamble = md_content[0:offset]
            parts.append(md_content[offset:span_offsets[i + 1]])
        elif i == len(span_offsets) - 1:
            parts.append(md_content[offset:])
        else:
            parts.append(md_content[offset:span_offsets[i + 1]])

    # Join the parts back together with the figure content inserted
    modified_content = ""
    if preamble:
        modified_content += preamble
    for i, part in enumerate(parts):
        modified_content += f"<!-- FigureContent=\"{figure_contents[i]}\" -->" + part

    return modified_content

def crop_image_from_pdf_page(pdf_path, page_number, bounding_box):
    """
    Crops a region from a given page in a PDF and returns it as an image.

    Args:    
    - pdf_path (pathlib.Path): Path to the PDF file.
    - page_number (int): The page number to crop from (0-indexed).
    - bounding_box (tuple): A tuple of (x0, y0, x1, y1) coordinates for the bounding box.
    
    Returns:
    - PIL.Image: A PIL Image of the cropped area.
    """
    doc = fitz.open(pdf_path)
    page = doc.load_page(page_number)
    
    # Cropping the page. The rect requires the coordinates in the format (x0, y0, x1, y1).
    bbx = [x * 72 for x in bounding_box]
    rect = fitz.Rect(bbx)
    pix = page.get_pixmap(matrix=fitz.Matrix(300 / 72, 300 / 72), clip=rect)
    
    img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    
    doc.close()

    return img

def format_content_understanding_result(content_understanding_result):
    """
    Formats the JSON output of the Content Understanding result as Markdown for downstream usage in text.
    
    Args:
    - content_understanding_result (dict): A dictionary containing the output from Content Understanding.

    Returns:
    - str: A Markdown string of the result content.
    """
    def _format_result(key, result):
        result_type = result["type"]
        if result_type in ["string", "integer", "number", "boolean"]:
            return f"**{key}**: " + str(result[f'value{result_type.capitalize()}']) + "\n"
        elif result_type == "array":
            return f"**{key}**: " + ', '.join([str(result["valueArray"][i][f"value{r['type'].capitalize()}"]) for i, r in enumerate(result["valueArray"])]) + "\n"
        elif result_type == "object":
            return f"**{key}**\n" + ''.join([_format_result(f"{key}.{k}", result["valueObject"][k]) for k in result["valueObject"]])

    fields = content_understanding_result['result']['contents'][0]['fields']
    markdown_result = ""
    for field in fields:
        markdown_result += _format_result(field, fields[field])

    return markdown_result

# %%
import io
import json
import os

# Run Content Understanding on each figure, format figure contents, and insert figure contents into corresponding document locations
with open(file, 'rb') as f:
    pdf_bytes = f.read()

    document_intelligence_client = DocumentIntelligenceClient(
        endpoint=AZURE_AI_SERVICE_ENDPOINT,
        api_version=AZURE_DOCUMENT_INTELLIGENCE_API_VERSION,
        credential=credential,
        output=str('figures')
    )

    poller = document_intelligence_client.begin_analyze_document(
        "prebuilt-layout",
        AnalyzeDocumentRequest(bytes_source=pdf_bytes),
        output=[str('figures')],
        features=['ocrHighResolution'],
        output_content_format="markdown"
    )

    result: AnalyzeResult = poller.result()
    
    md_content = result.content

    figure_contents = []
    if result.figures:
        print("Extracting figure contents with Content Understanding.")
        for figure_idx, figure in enumerate(result.figures):
            for region in figure.bounding_regions:
                    # Uncomment the below to print out the bounding regions of each figure
                    # print(f"Figure {figure_idx + 1} body bounding regions: {region}")
                    # To learn more about bounding regions, see https://aka.ms/bounding-region
                    bounding_box = (
                            region.polygon[0],  # x0 (left)
                            region.polygon[1],  # y0 (top
                            region.polygon[4],  # x1 (right)
                            region.polygon[5]   # y1 (bottom)
                        )
            page_number = figure.bounding_regions[0]['pageNumber']
            cropped_img = crop_image_from_pdf_page(file, page_number - 1, bounding_box)

            os.makedirs("figures", exist_ok=True)

            figure_filename = f"figure_{figure_idx + 1}.png"
            # Full path for the file
            figure_filepath = os.path.join("figures", figure_filename)

            # Save the figure
            cropped_img.save(figure_filepath)
            bytes_io = io.BytesIO()
            cropped_img.save(bytes_io, format='PNG')
            cropped_img = bytes_io.getvalue()

            # Collect formatted content from the figure
            content_understanding_response = content_understanding_client.begin_analyze(ANALYZER_ID, figure_filepath)
            content_understanding_result = content_understanding_client.poll_result(content_understanding_response, timeout_seconds=1000)
            figure_content = format_content_understanding_result(content_understanding_result)
            figure_contents.append(figure_content)
            print(f"Figure {figure_idx + 1} contents:\n{figure_content}")

        # Insert figure content into corresponding location in document
        md_content = insert_figure_contents(md_content, figure_contents, [f.spans[0]["offset"] for f in result.figures])
    
    # Save results as a JSON file to cache the result for downstream use
    result.content = md_content
    output = {}
    output['analyzeResult'] = result.as_dict()
    output = json.dumps(output)
    with open('sample_report.cache', 'w') as f:
        f.write(output)
# Out:
# Extracting figure contents with Content Understanding.
# Figure 1 contents:
# **Title**: SANGMYUNG UNIVERSITY
# **ChartType**: bar
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image is a logo for Sangmyung University. It features the name of the university in both Korean (상명대학교) and English (SANGMYUNG UNIVERSITY). The logo has a blue and yellow color scheme, with the Korean text in a bold, modern font and the English text in a smaller, simpler font below it. The left side of the logo contains a stylized design that includes Korean characters arranged vertically within a blue square.
# **Summary**: This is the logo for Sangmyung University, displaying its name in both Korean and English, with a distinctive blue and yellow color scheme.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 2 contents:
# **Title**: 신입생 2024 대학생활 안내
# **ChartType**: rings
# **TopicKeywords**: Education and academics, Student life, University guide
# **DetailedDescription**: The image is a colorful illustration depicting a classroom setting with students engaged in various activities. The title, written in Korean, translates to 'Freshman 2024 University Life Guide'. The students are shown sitting in a tiered lecture hall, each involved in different academic or leisure activities. Some are using laptops, others are reading books, and one is holding a flask, suggesting a science experiment. The students are diverse in appearance, and the setting is vibrant, indicating a lively and engaging university environment.
# **Summary**: The illustration serves as a guide for new university students in 2024, showcasing a dynamic and diverse academic environment. It highlights various aspects of student life, including studying, reading, and conducting experiments, in a lecture hall setting.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 3 contents:
# **Title**: 상명대학교 학사안내 절차
# **ChartType**: treemap
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The diagram outlines the steps for accessing academic information at Sangmyung University. It starts with visiting the university's homepage for academic guidance. The next step involves checking the academic system and class schedule. Following that, there is an online academic guide. Finally, it suggests referring to the '신편입생 온라인 학사안내' post for new and transfer students.
# **Summary**: This diagram provides a step-by-step guide for students at Sangmyung University to access academic information, starting from the university homepage to specific online resources for new and transfer students.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 4 contents:
# **Title**: 상명대학교
# **ChartType**: treemap
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image shows a section of a building with large glass windows and potted plants inside. The left side of the image features a vertical blue menu with white text, which appears to be a navigation menu for a university website. The menu includes options such as '상명소개', '입학안내', '대학ㆍ대학원', '연구ㆍ산학', '학사안내', and '대학생활'. The highlighted menu item is '학사안내', which is marked with a red box. The bottom of the menu has options for language selection, including 'ENG', 'CHN', and 'VNM'. The image is likely a screenshot from a virtual tour or informational page for Sangmyung University.
# **Summary**: The image is a screenshot from a Sangmyung University webpage, showing a building interior with a navigation menu on the left. The menu is in Korean and includes various sections related to university information, with '학사안내' highlighted. The page seems to be part of a virtual tour or informational resource for prospective or current students.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 상명대학교
#
# Figure 5 contents:
# **Title**: 2023학년도 성결대학교 학사안내
# **ChartType**: pie
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image shows a webpage from the website of 성결대학교 (Sungkyul University). The webpage is titled '2023학년도 성결대학교 학사안내', which translates to '2023 Academic Guide for Sungkyul University'. The left side of the image displays a navigation menu with various options related to academic information, such as '학사안내' (Academic Guide), '교과목 개요' (Course Overview), and '교육과정' (Curriculum). The main content area on the right side of the image appears to be a video or presentation related to the academic guide for the year 2023, as indicated by the title at the top of the content area.
# **Summary**: The image is a screenshot of a webpage from Sungkyul University, providing an academic guide for the year 2023. It includes a navigation menu with options for academic information and a main content area featuring a video or presentation.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 6 contents:
# **Title**: 상명대학교
# **ChartType**: pie
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image shows a statue of a deer against a cloudy sky, with a navigation menu on the left side of the screen. The menu includes options such as '소개', '입학안내', '대학ㆍ대학원', '연구ㆍ산학', '학사안내', and '대학생활'. There is a 'Login' button highlighted in red. The bottom of the image has a play button and navigation dots, indicating a slideshow or gallery format. The text '상명대학교' is visible at the bottom right corner of the image, which translates to 'Sangmyung University'.
# **Summary**: The image is a web page screenshot from Sangmyung University, featuring a deer statue and a navigation menu with various options related to university information. A 'Login' button is prominently highlighted.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 상명대학교
#
# Figure 7 contents:
# **Title**: SANGMYUNG 수강신청로그인
# **ChartType**: bar
# **TopicKeywords**: Education and academics, Technology, User interface
# **DetailedDescription**: The image shows a login interface for SANGMYUNG 수강신청로그인, which appears to be a course registration system for Sangmyung University. The interface includes fields for entering a student ID and password, with an option to check a box labeled '비밀번호 초기화' (Password Reset). There is a blue '로그인' (Login) button below these fields. To the right of the login fields, there is a button labeled '회원가입' (Sign Up). The interface also includes a warning message in red text at the bottom, advising users to check their information if they encounter issues logging in. On the left side of the image, there is a laptop displaying a dashboard with various charts and graphs, suggesting that the system provides analytical tools or data visualization features.
# **Summary**: The image depicts a login page for Sangmyung University's course registration system, featuring fields for student ID and password, a password reset option, and a sign-up button. A laptop on the left shows a dashboard, indicating the system's analytical capabilities.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The red text at the bottom advises users to verify their information if login issues occur.
#
# Figure 8 contents:
# **Title**:
# **ChartType**: bar
# **TopicKeywords**: Arts and culture, Technology
# **DetailedDescription**: The image is a cartoon illustration of a cute character with antlers, sitting in front of a computer. The character has a round face, small eyes, and a small mouth, with blush on its cheeks. It is wearing a blue scarf and has a small tail. The character is depicted in a simple, cute style, often associated with kawaii culture.
# **Summary**: The image is a cartoon character with antlers, sitting at a computer, depicted in a cute and simple style.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 9 contents:
# **Title**: 학번/교직원번호 조회
# **ChartType**: bar
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image is a form for querying student or staff numbers, titled '학번/교직원번호 조회'. It requires users to authenticate their identity via mobile phone. The form includes fields for name, date of birth, gender, and nationality. There are two buttons at the bottom: one for requesting authentication and another for canceling the process. The form emphasizes the importance of entering accurate information as indicated by the asterisk note at the top.
# **Summary**: The image shows a form for retrieving student or staff numbers, requiring mobile phone authentication. Users must input personal details such as name, birth date, gender, and nationality. The form highlights the necessity of accurate information entry.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: * 반드시 본인 명의의 휴대폰으로 인증해야 합니다. (You must authenticate with a mobile phone registered in your name.)
#
# Figure 10 contents:
# **Title**: 학번/교직원번호 조회
# **ChartType**: bar
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image is a user interface for querying student or staff numbers. It includes a lock icon and the title '학번/교직원번호 조회', which translates to 'Student/Staff Number Inquiry'. The interface provides instructions and fields for entering information such as the name, student/staff number, and department. There are buttons labeled '재조회' (Re-query), '비밀번호 변경' (Change Password), and '돌아가기' (Go Back).
# **Summary**: The image is a user interface for querying student or staff numbers, with options to re-query, change password, or go back.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 상명인 2019XXXXX | XX학과 이름(학번/교직원번호) | 부서명
#
# Figure 11 contents:
# **Title**: 서약서 및 동의서
# **ChartType**: box
# **TopicKeywords**: Consent, Legal, Privacy
# **DetailedDescription**: The image shows a consent form titled '서약서 및 동의서' which translates to 'Pledge and Consent Form'. It includes checkboxes for agreeing to terms related to personal information processing and risk information. The first section is about consent to the processing of personal information by Sangmyung University, with a detailed paragraph explaining the terms. The second section is about consent to risk information, with a brief explanation. There are checkboxes for agreeing to each section, and a submit button at the bottom.
# **Summary**: The document is a consent form from Sangmyung University, requiring agreement to terms regarding personal information processing and risk information. Users must check the boxes to agree before submitting.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 상명대학교 개인정보 처리방침 동의서
# 위험정보에 대한 동의
#
# Figure 12 contents:
# **Title**: Form Submission Page
# **ChartType**: treemap
# **TopicKeywords**: Data entry, User interface, Web forms
# **DetailedDescription**: The image shows a web form interface with multiple fields for data entry. The form is divided into two main sections, each outlined in red. The first section includes fields for personal information such as name, date of birth, and contact details. The second section appears to be for additional information, possibly related to employment or other personal details. There is a blue button labeled '저장' (Save) at the bottom of the form. The form is accompanied by several bullet points in Korean, which likely provide instructions or important notes for filling out the form.
# **Summary**: The image depicts a web form with sections for entering personal and possibly employment-related information. It includes fields for name, date of birth, and contact details, with a save button at the bottom. Instructions in Korean are provided above the form.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The form includes several bullet points in Korean, which likely provide instructions or important notes for filling out the form.
#
# Figure 13 contents:
# **Title**: 상명대학교 홈페이지 대학생활 IT 서비스 모바일 서비스 안내 스마트출결 참조
# **ChartType**: treemap
# **TopicKeywords**: Education and academics, Mobile services, Technology
# **DetailedDescription**: The diagram is a flowchart that outlines a sequence of steps or categories related to IT services and mobile service guidance at Sangmyung University. It starts with the university's homepage and student life section, then moves to IT services, followed by mobile service guidance, and finally references smart attendance. Each step is enclosed in a dotted circle, and arrows indicate the flow from one step to the next.
# **Summary**: This flowchart provides a step-by-step guide starting from the Sangmyung University homepage, navigating through IT services, mobile service guidance, and ending with smart attendance reference. It is likely used to help students or users find specific services or information on the university's website.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 14 contents:
# **Title**: 상명대학교 스마트출결 시스템
# **ChartType**: pie
# **TopicKeywords**: Education and academics, Technology, University services
# **DetailedDescription**: The image consists of three screenshots related to the Smart Attendance System at Sangmyung University. The first screenshot shows a menu from the university's website, highlighting the 'IT Services' section. The second screenshot provides detailed instructions on how to use the Smart Attendance System, including steps for setting it up and using its features. The third screenshot is a YouTube video thumbnail titled 'Sangmyung University Smart Attendance System [Setup Method and Usage Functions]'.
# **Summary**: The image provides a visual guide to the Smart Attendance System at Sangmyung University, including website navigation, setup instructions, and a video tutorial.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The images include navigation instructions and a video tutorial for the Smart Attendance System at Sangmyung University.
#
# Figure 15 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Cartoons and comics
# **DetailedDescription**: The image is a cartoon illustration of a cute character resembling a deer or a similar animal. It has antlers shaped like the Japanese characters for 'deer' (シカ). The character is holding a megaphone and appears to be speaking or making an announcement. It has a round face with blush marks on its cheeks, a small nose, and a smiling mouth. The character is wearing a blue scarf around its neck and has a small white patch on its belly. The overall style is simplistic and cute, typical of Japanese mascot characters.
# **Summary**: This is a cartoon image of a deer-like character with antlers shaped like Japanese characters, holding a megaphone. It is designed in a cute and simplistic style, often used for mascots.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 16 contents:
# **Title**:
# **ChartType**: bar
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image is a cartoon illustration of a cute character with antlers, resembling a deer, sitting at a desk and writing on a piece of paper labeled 'TEST'. The character has a round face with blush on its cheeks, a small smile, and is holding a pen in its right hand. The antlers are stylized to resemble the Japanese characters for 'deer' (シカ). The character appears to be focused on the task at hand, suggesting a theme of education or examination.
# **Summary**: The image depicts a cartoon character with antlers, resembling a deer, writing a test. The character is cute and focused, suggesting themes of education and academics.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 17 contents:
# **Title**: Sangmyung University Integrated Login
# **ChartType**: box
# **TopicKeywords**: Education and academics, Technology, User interface
# **DetailedDescription**: The image shows the login interface for Sangmyung University's integrated system. On the right side, there is a login box where users can enter their username and password. There is also an option to toggle between Korean and English languages. Below the login fields, there are options for '학생/직원/학부모' (Student/Staff/Parent) and '로그인 후 자동접속' (Auto-connect after login). On the left side, there is a pop-up box with important notices regarding login procedures and requirements, including browser compatibility and security settings.
# **Summary**: The image depicts the login page for Sangmyung University's integrated system, featuring a login form and a notice box with instructions and requirements for successful login.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The login page includes a notice about browser compatibility and security settings, advising users to use Internet Explorer or a compatible browser and to adjust security settings if necessary.
#
# Figure 18 contents:
# **Title**: 샘물 비밀번호 초기화
# **ChartType**: bar
# **TopicKeywords**: Education and academics, Security, Technology
# **DetailedDescription**: The image is a login screen for Sangmyung University, featuring a password reset option. It includes a laptop displaying a dashboard with various charts and data, indicating a focus on academic or administrative information. The main section of the image provides options for resetting passwords for different user categories: enrolled students, faculty, alumni, and OTP (One-Time Password) users. Each category is represented by a button, suggesting a user-friendly interface for password management.
# **Summary**: The image is a password reset interface for Sangmyung University, offering options for different user groups such as students, faculty, and alumni. It emphasizes security and user accessibility in managing login credentials.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 샘물 통합로그인 (Sangmyung Integrated Login)
#
# Figure 19 contents:
# **Title**: SANGMYUNG 포털시스템
# **ChartType**: bar
# **TopicKeywords**: Education and academics, Technology
# **DetailedDescription**: The image is a screenshot of the Sangmyung University portal system interface. It includes a navigation bar at the top with options such as 통합정보 (Integrated Information), 전자결재 (Electronic Approval), e-Campus, e-포트폴리오 (e-Portfolio), and 학습정보공 (Learning Information). Below the navigation bar, there is a section titled '공지사항' (Notices) with a list of announcements, including details like the title, date, and department. On the right side, there is a calendar section showing the academic schedule for January 2024. At the bottom, there is a menu with icons for various functions, including 'Office365', which is highlighted in red.
# **Summary**: The image shows the Sangmyung University portal interface, featuring navigation options for integrated information, electronic approval, and more. It highlights the 'Office365' option, indicating its availability for users. The interface also displays a list of announcements and an academic calendar for January 2024.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The 'Office365' option is highlighted in red, indicating its importance or recent addition to the portal.
#
# Figure 20 contents:
# **Title**: Microsoft 365 계정 생성
# **ChartType**: box
# **TopicKeywords**: Software, Technology, User Interface
# **DetailedDescription**: The image shows a user interface for creating a Microsoft 365 account. It includes two main sections: '서비스 이용 약관' (Service Terms of Use) and '개인정보 처리방침' (Personal Information Processing Policy). Each section contains a scrollable text box with terms and conditions written in Korean. Below each text box, there is a checkbox that the user must check to agree to the terms. The first checkbox is labeled '위의 서비스 이용 약관에 동의합니다.' (I agree to the above service terms of use), and the second checkbox is labeled '위의 개인정보 처리방침에 동의합니다.' (I agree to the above personal information processing policy). At the bottom, there are two buttons: a blue '다음' (Next) button and a gray '취소' (Cancel) button.
# **Summary**: The interface is for creating a Microsoft 365 account, requiring users to agree to service terms and a privacy policy by checking respective boxes before proceeding.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The checkboxes and buttons are highlighted with red boxes for emphasis.
#
# Figure 21 contents:
# **Title**: 상명대학교 Application Selection
# **ChartType**: rings
# **TopicKeywords**: Education and academics, Technology, User interface
# **DetailedDescription**: The image is a user interface screen from Sangmyung University, prompting users to select an application. It features the university's logo at the top, followed by a message in Korean instructing users to select an application. Below this message, there are two options: Outlook and Office, each represented by their respective icons. At the bottom, there is a blue button labeled '로그인' (Login). The interface also includes language selection options with flags for Korea, the USA, and China, and a help icon on the right side.
# **Summary**: This is a user interface from Sangmyung University for selecting between Outlook and Office applications. It includes language options and a login button.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The text in Korean instructs users to select an application. The login button is labeled '로그인' in Korean. Language options are available for Korean, English, and Chinese.
#
# Figure 22 contents:
# **Title**: 앱 및 디바이스
# **ChartType**: bar
# **TopicKeywords**: Office Suite, Software, Technology
# **DetailedDescription**: The image shows a section of a software interface for installing Microsoft Office applications. The interface is in Korean and includes options for selecting the language and version of the Office suite to be installed. The language is set to Korean (대한민국), and the version is set to 64-bit. There is a prominent red button labeled 'Office 설치' which means 'Install Office'. Icons for various Office applications such as Word, Excel, PowerPoint, and Outlook are displayed at the top right corner.
# **Summary**: The image is a software interface for installing Microsoft Office, with options to select language and version. It is set to Korean language and 64-bit version, with a button to install Office.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 23 contents:
# **Title**:
# **ChartType**: bar
# **TopicKeywords**: Arts and culture, Entertainment
# **DetailedDescription**: The image is a cartoon illustration of a cute character with antlers, sitting in front of a computer. The character has a round face with small eyes and a simple mouth, and its cheeks are slightly pink, giving it a blushing appearance. It is wearing a blue scarf and has a small tail. The character's antlers have a unique design, resembling the Japanese characters for 'deer' (鹿). The computer is a simple, modern design with a flat screen and a stand.
# **Summary**: The image is a cartoon character with antlers, sitting in front of a computer, likely representing a cute or humorous depiction of a deer using technology.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 24 contents:
# **Title**:
# **ChartType**: bar
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image is a cartoon illustration of a character that resembles a deer or a reindeer. The character is holding a megaphone and appears to be making an announcement. It has antlers with symbols on them, one resembling a male symbol and the other a female symbol. The character is wearing a blue scarf and has a small tail. The style is cute and simplistic, with a focus on rounded shapes and soft colors.
# **Summary**: The image is a cartoon character, possibly a mascot, depicted as a deer with antlers featuring gender symbols. It is holding a megaphone, suggesting it is making an announcement or call to action. The character is designed in a cute and approachable style.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 25 contents:
# **Title**: Campus Map with Wi-Fi Access Points
# **ChartType**: treemap
# **TopicKeywords**: Access Points, Campus, Map, Wi-Fi
# **DetailedDescription**: The image is a map of a campus with various buildings marked. Each building is represented by a circle, with some circles outlined in red and others in blue. The legend at the top left corner indicates that red circles represent buildings with '전용AP 장비' (dedicated AP equipment) and blue circles represent buildings with '일반AP 장비' (general AP equipment). The map includes various buildings such as libraries, lecture halls, and administrative offices, each labeled in Korean. The map also features two cartoon characters at the bottom, adding a playful element to the design.
# **Summary**: The map provides a visual representation of a campus, highlighting the distribution of Wi-Fi access points across different buildings. Red circles indicate buildings with dedicated AP equipment, while blue circles indicate those with general AP equipment. This map is useful for understanding the Wi-Fi infrastructure on campus.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: Legend:
# - Red circle: 전용AP 장비 (Dedicated AP equipment)
# - Blue circle: 일반AP 장비 (General AP equipment)
#
# Figure 26 contents:
# **Title**: 전자문서함
# **ChartType**: treemap
# **TopicKeywords**: Business and finance, Communication, Technology
# **DetailedDescription**: The image shows a screenshot of an electronic document management system interface. The interface is divided into several sections. On the left, there is a navigation panel with options like '전자문서함', '업무관리', '메시지', '주소록', '게시판', '일정', '설문', and '설정'. The main section is titled '전자문서함' (Electronic Document Box) and contains a table with columns for '문서번호' (Document Number), '문서제목' (Document Title), '기안자' (Drafter), '기안일자' (Draft Date), and '상태' (Status). The table lists a document with the title '테스트 문서입니다.' (This is a test document), drafted by '홍길동' on '2023-10-10', with a status of '결재완료' (Approval Completed). On the right, there is a detailed view of the selected document, showing its content and metadata. The top right corner has a button labeled '문서작성' (Create Document).
# **Summary**: The interface is a document management system where users can view and manage electronic documents. It features a navigation panel for different sections and a main area displaying document details. A specific document titled '테스트 문서입니다.' is shown, drafted by '홍길동' and marked as '결재완료'.
# **MarkdownDataTable**: | 문서번호 | 문서제목          | 기안자 | 기안일자   | 상태       |
# |----------|-------------------|--------|------------|------------|
# | 1        | 테스트 문서입니다. | 홍길동 | 2023-10-10 | 결재완료   |
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The document is a test document, and the status indicates it has been approved. The interface allows for document creation and management.
#
# Figure 27 contents:
# **Title**: 세입세출결산서
# **ChartType**: bar
# **TopicKeywords**: Business and finance
# **DetailedDescription**: The image shows a financial statement titled '세입세출결산서', which translates to 'Revenue and Expenditure Settlement Statement'. It includes a table with columns for the year (회계연도), budget (예산액), and settlement amount (결산액). The table compares data for the years 2021 and 2022. For 2021, the budget was 2,000,000 and the settlement amount was 1,800,000. For 2022, the budget was 2,500,000 and the settlement amount was 2,300,000. The table also includes columns for the difference between the budget and settlement amounts (차이), which are 200,000 for 2021 and 200,000 for 2022. The table is part of a larger financial report, which includes additional sections and annotations.
# **Summary**: The financial statement compares budgeted and settled amounts for the years 2021 and 2022. In both years, the settlement amounts were slightly less than the budgeted amounts, with a consistent difference of 200,000 each year.
# **MarkdownDataTable**: | 회계연도 | 예산액   | 결산액   | 차이   |
# |---------|---------|---------|-------|
# | 2021    | 2,000,000 | 1,800,000 | 200,000 |
# | 2022    | 2,500,000 | 2,300,000 | 200,000 |
# **AxisTitles**
# **AxisTitles.xAxisTitle**: Year
# **AxisTitles.yAxisTitle**: Amount
# **FootnotesAndAnnotations**: The document includes a note about Adobe Reader and a disclaimer about the accuracy of the data.
#
# Figure 28 contents:
# **Title**: 기본정보
# **ChartType**: bar
# **TopicKeywords**: Business and finance
# **DetailedDescription**: The image shows a table with various columns and rows, likely related to business or financial data. The table includes columns for '기준년도' (Base Year), '기준월' (Base Month), '기준일' (Base Day), '기준시간' (Base Time), '기준분' (Base Minute), and '기준초' (Base Second). There are two rows of data, one for the year 2023 and another for 2022. The data for 2023 is complete with values for each column, while the data for 2022 is partially filled. The table also includes a section titled '기본정보' (Basic Information) with various fields such as '이름' (Name), '생년월일' (Date of Birth), '성별' (Gender), '전화번호' (Phone Number), and '이메일' (Email).
# **Summary**: The table provides a structured view of basic information and time-based data for the years 2023 and 2022. It includes detailed fields for personal information and specific time metrics, with complete data for 2023 and partial data for 2022.
# **MarkdownDataTable**: | 기준년도 | 기준월 | 기준일 | 기준시간 | 기준분 | 기준초 |
# |---------|--------|--------|----------|--------|--------|
# | 2023    | 10     | 25     | 14       | 30     | 45     |
# | 2022    |        |        |          |        |        |
# **AxisTitles**
# **AxisTitles.xAxisTitle**: 기준년도
# **AxisTitles.yAxisTitle**: 기준월
# **FootnotesAndAnnotations**: 기본정보: 이름, 생년월일, 성별, 전화번호, 이메일 등.
#
# Figure 29 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image is a cartoon illustration of a character resembling a deer or moose. The character has antlers shaped like the Chinese characters for 'male' (男) and 'female' (女). It is holding a magnifying glass in front of its face, which enlarges one of its eyes. The character is wearing a blue scarf with the letters 'SMU' on it, indicating a possible affiliation with Singapore Management University. The character has a cute and friendly appearance, with blush marks on its cheeks and a small smile.
# **Summary**: The image depicts a cartoon character with antlers shaped like gender symbols, holding a magnifying glass. It wears a scarf labeled 'SMU', suggesting a connection to Singapore Management University.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 30 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image is a cartoon character, likely a mascot, wearing a blue outfit with the letters 'SMU' on it. The character has antlers shaped like a key and an arrow, and is holding a pointer stick. The character has a round face with pink cheeks and a small smile.
# **Summary**: The image depicts a cartoon mascot character associated with SMU, characterized by unique antlers and a friendly demeanor.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 31 contents:
# **Title**: Cute Character Writing a Test
# **ChartType**: bar
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image depicts a cute cartoon character with antlers, resembling a deer, sitting at a desk and writing on a piece of paper labeled 'TEST'. The character has a round face with blush marks on its cheeks, a small smile, and is holding a pen in its right hand. The character's antlers are stylized and the overall design is simplistic and adorable, likely intended to appeal to a younger audience or to be used in educational materials.
# **Summary**: A cartoon character with antlers is shown writing a test, suggesting themes of education and learning. The character's cute and simplistic design makes it appealing for educational or cultural contexts.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 32 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture
# **DetailedDescription**: The image is a cartoon illustration of a character resembling a deer or a similar animal. It has antlers shaped like the Chinese character '丰' and is holding a basket filled with flowers. The character is wearing a blue scarf with the letters 'SMU' on it. The character is depicted in a playful pose, with one leg raised and flowers falling out of the basket.
# **Summary**: The image is a cartoon character with antlers shaped like the Chinese character '丰', holding a basket of flowers and wearing an 'SMU' scarf.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 33 contents:
# **Title**: SMU Mascot Characters
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image features two cartoon characters that appear to be mascots for SMU, as indicated by the letters on their shirts. Both characters are depicted as cute animals with antlers, resembling deer. They are wearing blue and white shirts, with one character holding a clipboard and pen, and the other holding a notepad and gesturing with a finger raised. The characters have a friendly and approachable design, with round faces, rosy cheeks, and small smiles.
# **Summary**: The image shows two SMU mascot characters, both resembling deer with antlers, wearing blue and white shirts. One holds a clipboard and pen, while the other holds a notepad and gestures with a raised finger. They are designed to be cute and approachable, likely representing a welcoming and academic spirit.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 34 contents:
# **Title**: Educational Domains and Skills
# **ChartType**: rings
# **TopicKeywords**: Education and academics, Learning domains, Skills development
# **DetailedDescription**: The image presents five educational domains, each represented by a cartoon character with a specific icon. The domains are: 1) Knowledge and Information Domain, which includes skills like knowledge acquisition, understanding, and cooperative problem-solving. 2) Creative Problem-Solving Domain, which focuses on critical thinking, idea generation, and problem-solving. 3) Science and Technology Domain, which covers scientific inquiry, knowledge connection, and creative problem-solving. 4) Diversity and Communication Domain, which emphasizes cultural understanding, communication, and empathy. 5) Ethical Practice Domain, which includes community awareness, life skills, and ethical understanding.
# **Summary**: The image categorizes educational skills into five domains: Knowledge and Information, Creative Problem-Solving, Science and Technology, Diversity and Communication, and Ethical Practice. Each domain is associated with specific skills, such as critical thinking, scientific inquiry, and cultural understanding.
# **MarkdownDataTable**: | Domain | Skills |
# |--------|--------|
# | Knowledge and Information | Knowledge acquisition, Understanding, Cooperative problem-solving |
# | Creative Problem-Solving | Critical thinking, Idea generation, Problem-solving |
# | Science and Technology | Scientific inquiry, Knowledge connection, Creative problem-solving |
# | Diversity and Communication | Cultural understanding, Communication, Empathy |
# | Ethical Practice | Community awareness, Life skills, Ethical understanding |
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 35 contents:
# **Title**: 학생활동종합정보시스템
# **ChartType**: treemap
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The diagram is a flowchart that outlines the process within a student activity information system. It starts with the '학생활동종합정보시스템' (Student Activity Information System), which leads to '종합정보' (Comprehensive Information). This is followed by '학생기본' (Student Basics), then '학생역량진단' (Student Competency Diagnosis), and finally '역량진단평가' (Competency Diagnosis Evaluation). The result of this process is the '학생별 역량 진단 평가현황' (Student-specific Competency Diagnosis Evaluation Status), which is displayed on a board held by a cartoon character.
# **Summary**: The diagram illustrates a process flow within a student activity information system, starting from comprehensive information collection to competency diagnosis and evaluation, resulting in a student-specific competency evaluation status.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 36 contents:
# **Title**: Radar Chart Comparison
# **ChartType**: radar
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image contains two radar charts side by side. The left chart compares the performance of students from 1st year to 4th year across five categories: '전문지식탐구' (Exploration of Professional Knowledge), '창의적 문제해결' (Creative Problem Solving), '윤리적 실천' (Ethical Practice), '다양성' (Diversity), and '융복합' (Convergence). Each year is represented by a different color: 1st year (blue), 2nd year (orange), 3rd year (gray), and 4th year (yellow). The right chart compares an individual's performance against the overall average in the same categories, with '나' (Me) in blue and '전체 평균' (Overall Average) in orange.
# **Summary**: The radar charts provide a visual comparison of student performance across different academic years and an individual's performance against the average. The left chart shows how students from 1st to 4th year perform in various academic and ethical categories, while the right chart compares an individual's performance to the overall average.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 1학년 (1st year), 2학년 (2nd year), 3학년 (3rd year), 4학년 (4th year), 나 (Me), 전체 평균 (Overall Average), 전문지식탐구 (Exploration of Professional Knowledge), 창의적 문제해결 (Creative Problem Solving), 윤리적 실천 (Ethical Practice), 다양성 (Diversity), 융복합 (Convergence)
#
# Figure 37 contents:
# **Title**: 오름교육 실천 + 오름교육 성과 > 오름 피날레
# **ChartType**: treemap
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The diagram illustrates a process flow in the context of education, specifically focusing on the '오름교육' (Orem Education) system. It consists of three main components: '오름교육 실천' (Orem Education Practice), '오름교육 성과' (Orem Education Outcomes), and '오름 피날레' (Orem Finale). The '오름교육 실천' section includes elements like '전공 나비효율' (Major Efficiency), '교양 나비효율' (Liberal Arts Efficiency), and '비교과 피어효율' (Extracurricular Peer Efficiency). The '오름교육 성과' section lists outcomes such as '교내외 수상' (Awards Inside and Outside School), '논문 게재' (Paper Publication), '특허' (Patents), '창업' (Startups), and '사회봉사' (Social Service). The final component, '오름 피날레', is described as a '스토리' (story) for student success, indicating a culmination of the educational process.
# **Summary**: The diagram represents a structured educational process under the '오름교육' system, highlighting the practice, outcomes, and final culmination in student success. It emphasizes efficiency in major, liberal arts, and extracurricular activities, leading to tangible outcomes like awards, publications, patents, startups, and social service, culminating in a narrative of student success.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 학생 성공을 위한 오름교육 스토리
#
# Figure 38 contents:
# **Title**: 2023학년도 1학기 상명 창의융복합 통합성과대회
# **ChartType**: treemap
# **TopicKeywords**: Education and academics, Festivals, Korean universities
# **DetailedDescription**: The image is a promotional poster for the 2023 first semester integrated performance competition at Sangmyung University. It features a colorful, cartoon-style illustration of a festival with various elements such as trees, buildings, and characters. The text on the poster is in Korean and includes the title of the event, '2023학년도 1학기 상명 창의융복합 통합성과대회', which translates to '2023 First Semester Sangmyung Creative Convergence Integrated Performance Competition'. The event is scheduled to take place from March 3, 2023, to August 21, 2023. The poster also includes a QR code and a URL for more information, as well as logos of the university and related educational institutions.
# **Summary**: The poster advertises a creative convergence festival at Sangmyung University for the first semester of 2023, running from March 3 to August 21. It features a vibrant illustration and provides a QR code and URL for further details.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 개최기간: 2023. 3. 3. ~ 8. 21. (금) Sangmyung University, Daehak-ro Campus. URL: https://naver.me/xN2YJ9Xk
#
# Figure 39 contents:
# **Title**: 2022학년도 2학기 상명 창의융복합 통합성과대회
# **ChartType**: treemap
# **TopicKeywords**: Education and academics, Events, Technology
# **DetailedDescription**: The image is a promotional poster for the 2022 Fall Semester Sangmyung Creative Convergence Integrated Performance Contest. The event is titled 'Night Festival' and is depicted with a colorful, isometric illustration of a festival scene. The scene includes various elements such as a circus tent, food stalls, a stage, and a drone, suggesting a vibrant and diverse event. The event is scheduled to take place from January 18, 2023, to February 6, 2023, and will be held in a virtual space called 'Metaverse' with a provided link for access. The poster includes logos of the supporting organizations, which are likely related to Sangmyung University and educational support services.
# **Summary**: The poster advertises a virtual event titled 'Night Festival' as part of the 2022 Fall Semester Sangmyung Creative Convergence Integrated Performance Contest. It will be held in the Metaverse from January 18 to February 6, 2023. The illustration suggests a lively festival atmosphere with various attractions.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 기간: 2023. 1. 18.(수)~2. 6.(월)
# 장소: 메타버스 (https://zep.us/play/2XP5yP)
#
# Figure 40 contents:
# **Title**: 2022학년도 1학기 상명 창의융합학부 통합설계과대회 여름교육 페스티벌
# **ChartType**: pie
# **TopicKeywords**: Education and academics, Events
# **DetailedDescription**: The image is a poster for the 2022 Summer Education Festival organized by the Sangmyung University Creative Convergence Department. The event is scheduled to take place from August 16, 2022, to August 26, 2022, at the Sangmyung University e-Campus in the SM-Class. The poster features cartoon characters and a light bulb design, symbolizing creativity and learning.
# **Summary**: The poster announces the 2022 Summer Education Festival by Sangmyung University's Creative Convergence Department, held from August 16 to August 26, 2022, at the university's e-Campus. It features a creative design with cartoon characters.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 개최장소: 상명대학교 e-Campus내 SM-Class
# 개최일정: 2022.8.16.(화) ~ 8.26.(금)
#
# Figure 41 contents:
# **Title**: SANGMYUNG 통합로그인
# **ChartType**: bar
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image shows a login page for Sangmyung University. It features a section for entering a student or employee number and a password. There are options to save the student/employee number, retrieve the student/employee number, retrieve the password, and access login help or usage information. The page is available in Korean and English, as indicated by a language toggle switch. A picture of a university building is displayed on a laptop screen on the left side of the page.
# **Summary**: This is a login interface for Sangmyung University, allowing students and employees to access their accounts by entering their ID and password. It includes options for retrieving forgotten credentials and is available in both Korean and English.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: KOR/ENG language toggle, options for ID and password retrieval, and login help.
#
# Figure 42 contents:
# **Title**: e-Campus Login Page
# **ChartType**: bar
# **TopicKeywords**: Education and academics, Technology, User interface
# **DetailedDescription**: The image shows the login page for the e-Campus platform of a university. The page includes fields for entering a username and password, with a login button. There are options for Korean and English language selection. The left side of the page contains a section for announcements, which includes information about system maintenance and updates. The right side features a promotional section for downloading the e-Campus mobile app, with instructions on how to access the app store and download the application. The background image is of a university campus, showing a large building and a road with people walking.
# **Summary**: The e-Campus login page provides access to the university's online platform, with options for language selection and a section for announcements. It also promotes the mobile app for easier access. The background features a university campus image.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: - 공지사항: 2017학년도 2학기 중간 기말고사 안내, VOD 서비스 일시 중단 안내, e-Campus 시스템 점검 안내
# - e-Campus 앱을 다운로드 받으세요: e-Campus 앱을 통해 모바일에서도 강의 수강 및 학습이 가능합니다. 앱스토어에서 '성균관대학교 e-Campus'를 검색하여 다운로드 받으세요.
#
# Figure 43 contents:
# **Title**: 비교과: 피어오름
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image features two cartoon deer characters sitting on a patch of grass, each holding a small plant in a pot labeled 'SMU'. The deer have antlers shaped like the Korean character 'ㅅ'. The grass is decorated with colorful flowers, and the text '비교과: 피어오름' is written in Korean at the bottom, which translates to 'Extracurricular: Blooming'. The image is likely a mascot or promotional graphic for an extracurricular program at SMU (Sangmyung University).
# ...
# | 8  | 교육과정    | EBE100C    | 2    | N        | Y          |
# | 9  | 교육과정    | EBE100D    | 2    | N        | Y          |
# | 10 | 교육과정    | EBE100E    | 2    | N        | Y          |
# **AxisTitles**
# **AxisTitles.xAxisTitle**: Course Details
# **AxisTitles.yAxisTitle**: Course Information
# **FootnotesAndAnnotations**: The interface includes options for filtering and searching courses, as well as a button for downloading the course plan.
#
# Figure 51 contents:
# **Title**: 상명대학교 비교과통합지원센터
# **ChartType**: pie
# **TopicKeywords**: Education and academics
# **DetailedDescription**: The image is a webpage screenshot from the Sangmyung University Non-Curricular Integrated Support Center. It features a navigation menu with options such as '비교과교육과정' (Non-Curricular Education Program), '비교과소개' (Introduction to Non-Curricular), '마이이음플랫폼' (My Connection Platform), '커뮤니티' (Community), and '센터소개' (Center Introduction). The main visual element is an illustration depicting a globe with various data and communication symbols, suggesting a focus on global or interconnected educational support. There is also a person working on a laptop, surrounded by charts and graphs, indicating a data-driven or analytical approach to education.
# **Summary**: The image is a screenshot of the Sangmyung University Non-Curricular Integrated Support Center's webpage. It highlights the center's focus on providing educational support through various non-curricular programs and platforms, with an emphasis on data and global connectivity.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 52 contents:
# **Title**: 상명대학교 비교과교육과정 '피어오름'
# **ChartType**: rings
# **TopicKeywords**: Education and academics, Social media, University programs
# **DetailedDescription**: The image is a screenshot of a YouTube channel page for '상명대학교 비교과교육과정 피어오름', which translates to 'Sangmyung University Extracurricular Education Program 'Piorum''. The page shows a series of video thumbnails under the '추천' (Recommended) and 'Shorts' sections. The recommended section includes videos with titles such as '피어오름 참여후기', '비교과과정의 모든 것', and 'Playlist | 상명대학교 비교과교육과정 피어오름'. The Shorts section features short video clips with various themes, including a music playlist, dance, and educational content. The channel has 74 subscribers and 47 videos.
# **Summary**: The YouTube channel '상명대학교 비교과교육과정 피어오름' features content related to Sangmyung University's extracurricular education program. It includes a variety of videos, from testimonials and educational content to music playlists and dance shorts. The channel has a modest following with 74 subscribers and 47 videos.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The channel has 74 subscribers and 47 videos.
#
# Figure 53 contents:
# **Title**:
# **ChartType**: bar
# **TopicKeywords**: Arts and culture, Technology
# **DetailedDescription**: The image is a cartoon illustration of a cute character with antlers, sitting in front of a computer. The character has a round face, small eyes, and a small mouth, with blush on its cheeks. It is wearing a blue scarf and has a small tail. The antlers have a unique design, resembling the symbols for male and female. The character is sitting on a chair, and the computer is on a desk in front of it.
# **Summary**: The image depicts a cartoon character with antlers, sitting at a computer. The character is designed in a cute style, with blush on its cheeks and a blue scarf. The antlers have a distinctive design, resembling gender symbols.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 54 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture
# **DetailedDescription**: The image is a cartoon illustration of a cute character resembling a deer or a similar animal. It has antlers shaped like the Chinese character for 'deer'. The character is holding a basket filled with flowers and is wearing a blue scarf with the letters 'SMU' on it. The character is depicted in a playful pose, with one leg raised and flowers falling out of the basket.
# **Summary**: The image is a cartoon character with antlers, holding a basket of flowers and wearing an 'SMU' scarf. It is a playful and cute illustration.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 55 contents:
# **Title**: 국가평생교육진흥원 홈페이지
# **ChartType**: treemap
# **TopicKeywords**: Education and academics, Korean education system, Online learning
# **DetailedDescription**: The image is a screenshot of the National Institute for Lifelong Education (NILE) website in South Korea. The website features a navigation menu at the top with categories such as '평생교육', '학점은행제', '독학학위제', '국가문해교육', '일반교육', '자료실', '정보공개', and '알림마당'. Below the menu, there are four main sections with images and icons: '평생교육진흥원 소개', '학점은행제', '독학학위제', and '문해교육'. Each section has a representative image and a descriptive icon. The lower part of the page includes links to various programs and announcements, such as '국가평생교육진흥원 프로그램', '추천링크', and '공지사항'. There is also a banner for COVID-19 related information.
# **Summary**: The image shows the homepage of the National Institute for Lifelong Education in South Korea, highlighting its main educational programs and services. The website is structured with a top navigation menu and sections dedicated to lifelong learning, credit banking, self-study degree programs, and literacy education. It also provides links to recommended resources and announcements.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: The website includes a COVID-19 information banner.
#
# Figure 56 contents:
# **Title**: 또래상담자 과정
# **ChartType**: rings
# **TopicKeywords**: Counseling, Education and academics, Peer support
# **DetailedDescription**: The diagram illustrates the process of becoming a peer counselor, depicted in four stages. The first stage is '기본교육' (basic education), where individuals receive foundational training. The second stage is '집단상담' (group counseling), where individuals participate in group counseling sessions. The third stage is '활동' (activities), where individuals engage in various counseling activities. The final stage is '수료' (completion), indicating the completion of the peer counseling program.
# **Summary**: The diagram outlines the four-step process for peer counselors, starting with basic education, followed by group counseling, then engaging in activities, and finally completing the program.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 57 contents:
# **Title**: Flowchart of Application and Counseling Process
# **ChartType**: treemap
# **TopicKeywords**: Application Process, Counseling, Psychological Assessment
# **DetailedDescription**: The flowchart outlines a four-step process for applying and receiving counseling and psychological assessment. The steps are as follows: 1) Application, which can be done through visit, phone, or email. 2) Request for counseling and psychological assessment. 3) Conducting an intake interview. 4) Conducting the counseling session and analyzing the psychological assessment.
# **Summary**: This flowchart illustrates the sequential steps involved in applying for and receiving counseling and psychological assessment services. It begins with the application process and ends with the counseling session and assessment analysis.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 58 contents:
# **Title**: 상담전화번호
# **ChartType**: bar
# **TopicKeywords**: Emergency contacts, Mental health, Support services
# **DetailedDescription**: The image provides a list of counseling and support hotlines in South Korea. It includes the following numbers: Sangmyung University Student Counseling Center at 02-2287-5328, Suicide Prevention Counseling at 109, Mental Health Counseling at 1577-0199, Youth Counseling at 1388, and Life Line at 1588-9191. These numbers are presented in a grid format, each within a pink-bordered box.
# **Summary**: The image lists several important counseling and support hotlines in South Korea, including services for students, suicide prevention, mental health, youth, and general life support.
# **MarkdownDataTable**: | Service                          | Phone Number |
# |---------------------------------|--------------|
# | Sangmyung University Student Counseling Center | 02-2287-5328 |
# | Suicide Prevention Counseling   | 109          |
# | Mental Health Counseling        | 1577-0199    |
# | Youth Counseling                | 1388         |
# | Life Line                       | 1588-9191    |
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 59 contents:
# **Title**: Flowchart of Consultation and Case Handling Process
# **ChartType**: treemap
# **TopicKeywords**: Case handling, Consultation, Legal process
# **DetailedDescription**: The flowchart outlines the process starting from a consultation application, followed by a consultation session. If the consultation concludes, the process ends there. Otherwise, a report and case reception occur, leading to a case investigation. Post-investigation, there are two possible paths: one involves the Investigation Committee's opinion and subsequent actions based on the results, and the other involves mediation through the Human Rights Center. The process concludes with case closure and follow-up actions.
# **Summary**: This flowchart illustrates the procedural steps from applying for a consultation to the conclusion of a case. It includes stages such as consultation, case investigation, and resolution through either committee review or mediation, ending with case closure.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 60 contents:
# **Title**:
# **ChartType**: bar
# **TopicKeywords**: Arts and culture
# **DetailedDescription**: The image is a cartoon illustration of a character with antlers, resembling a deer or a moose. The character is holding a clipboard and a pen, suggesting it is writing or drawing something. The character has a round face with blush on its cheeks, small eyes, and a small mouth, giving it a cute and friendly appearance. It is wearing a blue and white outfit.
# **Summary**: The image depicts a cartoon character with antlers, holding a clipboard and pen, likely engaged in writing or drawing. The character has a cute and friendly design, with a round face and blush on its cheeks.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 61 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image is a cartoon character resembling a deer with antlers, wearing a blue outfit with the letters 'SMU' on it. The character is holding a spoon and a bowl, suggesting a theme related to food or dining. The character has a cheerful expression with closed eyes and a smiling mouth, and its cheeks are highlighted with pink blush.
# **Summary**: The image depicts a cartoon deer character associated with SMU, possibly a mascot or promotional figure, holding a spoon and bowl, indicating a theme related to food or dining.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 62 contents:
# **Title**:
# **ChartType**: pie
# **TopicKeywords**: Arts and culture, Education and academics
# **DetailedDescription**: The image is a cartoon character resembling a deer with antlers shaped like the male and female gender symbols. The character is wearing a blue sash with the letters 'SMU' on it, indicating a connection to Singapore Management University. It is holding pink pom-poms in both hands, suggesting a cheerleading or supportive role. The character has a cheerful expression with closed eyes and a wide smile, and its cheeks are slightly blushed.
# **Summary**: The image depicts a cartoon mascot for Singapore Management University, characterized by its unique antlers and cheerful demeanor, likely used for promotional or school spirit purposes.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**:
#
# Figure 63 contents:
# **Title**: 개인형 이동장치 (전동킥보드 등) 교내 출입 및 통행 금지
# **ChartType**: bar
# **TopicKeywords**: Campus Regulations, Safety, Transportation
# **DetailedDescription**: The image is a public notice from Sangmyung University, prohibiting the use of personal mobility devices, such as electric scooters, within the campus. The notice highlights the steep terrain of the Seoul campus, which increases the risk of severe accidents. For the safety of the university community, the use of personal mobility devices on campus is strictly prohibited. The notice includes a cartoon image of a deer on a scooter with a 'NO!' sign, emphasizing the prohibition.
# **Summary**: Sangmyung University prohibits the use of personal mobility devices like electric scooters on its Seoul campus due to steep terrain and safety concerns.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 서울캠퍼스 전역이 경사가 매우 심해 운행사고 발생 시 큰 사고로 이어질 가능성이 높습니다. 상명구성원의 안전을 위하여 개인형 이동장치의 교내 출입 및 통행 전면 금지합니다.
#
# Figure 64 contents:
# **Title**: Campus Map
# **ChartType**: treemap
# **TopicKeywords**: Campus, Education, Navigation
# **DetailedDescription**: The image is a map of a campus with various buildings labeled with letters and corresponding descriptions. The buildings include academic departments, administrative offices, and facilities such as libraries and sports centers. Each building is marked with a letter, and a legend at the bottom provides the full name of each building. For example, 'A' represents the College of Social Sciences, 'B' is the College of Humanities, 'C' is the Family Hall, and so on. The map also includes paths and roads connecting these buildings, with some areas marked for specific purposes like sports or administration.
# **Summary**: This is a campus map showing the layout of various buildings and facilities, each labeled with a letter. The legend provides the names of these buildings, which include academic departments, administrative offices, and other facilities. The map helps in navigating the campus by showing the relative locations of these buildings.
# **MarkdownDataTable**: | Letter | Building Name                   |
# |--------|--------------------------------|
# | A      | College of Social Sciences     |
# | B      | College of Humanities          |
# | C      | Family Hall                    |
# | D      | Life Sciences Hall             |
# | E      | Gymnasium/Sports Center        |
# | F      | First Engineering Hall         |
# | G      | University Headquarters        |
# | H      | Second Engineering Hall        |
# | I      | College of Natural Sciences    |
# | J      | Library                        |
# | K      | Student Center                 |
# | L      | College of Business            |
# | M      | College of Arts                |
# | N      | College of Music               |
# | O      | College of Education           |
# | P      | College of Law                 |
# | Q      | College of Medicine            |
# | R      | Future Hall                    |
# | S      | Central Library                |
# | T      | College of Engineering         |
# | U      | Cultural Center                |
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: 1. Bus Stop 1
# 2. Bus Stop 2
# 3. Bus Stop 3
# 4. Bus Stop 4
# 5. Shuttle Bus Stop

# %%
# Uncomment the first line below to load in a previously cached result.
# output = open("sample_report.cache").read()
document_content = json.loads(output)
document_content = document_content['analyzeResult']['content']

# %% [markdown]
# ## 🔨 Chunk text by splitting with Markdown header splitting and recursive character splitting
# This is a simple starting point. Feel free to give your own chunking strategies a try!

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Configure langchain text splitting settings
EMBEDDING_CHUNK_SIZE = 512
EMBEDDING_CHUNK_OVERLAP = 20
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3")
]

# First split text using Markdown headers
text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on, strip_headers=False)
chunks = text_splitter.split_text(document_content)

# Then further split the text using recursive character text splitting
char_text_splitter = RecursiveCharacterTextSplitter(separators=["<!--", "\n\n", "#"], chunk_size=EMBEDDING_CHUNK_SIZE, chunk_overlap=EMBEDDING_CHUNK_OVERLAP, is_separator_regex=True)
chunks = char_text_splitter.split_documents(chunks)

print("Number of chunks: " + str(len(chunks)))
# Out:
# Number of chunks: 295

# %% [markdown]
# ## 🧪 Query vector index to retrieve relevant documents

# %%
from langchain_openai import AzureOpenAIEmbeddings
from langchain.vectorstores.azuresearch import AzureSearch

aoai_embeddings = AzureOpenAIEmbeddings(model=AZURE_OPENAI_EMBEDDING_DEPLOYMENT_NAME,
                                        azure_endpoint=AZURE_OPENAI_ENDPOINT,
                                        api_key=AZURE_OPENAI_API_KEY)

vector_store = AzureSearch(
    azure_search_endpoint=AZURE_SEARCH_ENDPOINT,
    azure_search_key=AZURE_SEARCH_API_KEY,
    index_name=AZURE_SEARCH_INDEX_NAME,
    embedding_function=aoai_embeddings.embed_query
)

# This is a one-time operation to add the documents to the vector store. Comment out this line if you are re-running this cell with the same index.
vector_store.add_documents(documents=chunks)

# Set up the retriever that will be used to query the index for similar documents
retriever = vector_store.as_retriever(search_type="similarity")

# %%
# Retrieve relevant documents
query = "Campus Map에 대해 설명해줘"
retrieved_docs = retriever.invoke(query)

# Print retrieved documents
for doc in retrieved_docs:
    print("Document id:", doc.metadata['id'])
    print("Content:", doc.page_content)
    print("=" * 50)
# Out:
# Document id: ZWY3ZjFhMTQtMmUxNy00MjA5LWI2NDktNTFiN2RjNzllMTMx
# Content: ### 3. 서비스 지역
# ※ 홈페이지 "상명소개>캠퍼스 안내>캠퍼스 맵>서울캠퍼스>무선(SM-wireless) 참조
# (https://www.smu.ac.kr/kor/intro/map_ap.do)
# <table>
# <tr>
# <th>구분</th>
# <th>서비스 지역 (무선AP 설치 공간]</th>
# <th>비고</th>
# </tr>
# <tr>
# <td>실내</td>
# <td>교직원, 재학생 및 졸업생</td>
# <td rowspan="2">[별첨] 서비스 맵 이미지 참조</td>
# </tr>
# <tr>
# <td>실외</td>
# <td>1. 중앙교수회관 앞(KB라운지 외부) 휴게 공간 2. 정문경비실 뒤쪽 휴게 공간 3. 학술정보관 앞, 5층 및 옥상 휴게 공간 4. 사범관 앞(편의점 정면) 및 4층 출입구 앞 휴게 공간 5. 미술관 앞(테니스장 방향) 및 뒤 휴게 공간</td>
# </tr>
# </table>
# ==================================================
# Document id: YThiZDI1OGEtMDk4MS00YjhmLTliZWUtOTc4NmRlMDU3NTAy
# Content: ## 2024학년도 캠퍼스맵
# ==================================================
# Document id: ZjEyNmFkMGQtYWQ5Zi00ZWRhLThiM2UtYTUzNzM0ZGQ3OWZl
# Content: # 학생복지시설 안내
# <table>
# <tr>
# <th>시설명</th>
# <th>위치</th>
# <th>서비스 내용</th>
# </tr>
# <tr>
# <td>보건건강관리센터</td>
# <td>학생회관 3층</td>
# <td>의료서비스</td>
# </tr>
# <tr>
# <td rowspan="13">라운지 &amp; 휴게실</td>
# <td>학생회관 2층</td>
# <td>학생 Lounge</td>
# </tr>
# <tr>
# <td>학생회관 1층</td>
# <td>SW Loungell</td>
# </tr>
# <tr>
# <td>월해관 2층</td>
# <td>학생 휴게실(일반)</td>
# </tr>
# <tr>
# <td>월해관 3층</td>
# <td>학생 휴게실(일반)</td>
# </tr>
# <tr>
# <td>인문사회과학대학관 2층</td>
# <td>SW Loungelll</td>
# </tr>
# <tr>
# <td>인문사회과학대학관 3층</td>
# <td>SW LoungeIV</td>
# </tr>
# <tr>
# <td>경영경제대학관 2층</td>
# <td>학생 Lounge</td>
# </tr>
# <tr>
# <td>중앙교수회관 1층</td>
# <td>KB STAR SQUARE</td>
# </tr>
# <tr>
# <td>사범대학관 1층</td>
# <td>LINC+ Creative Thinking Lounge</td>
# </tr>
# <tr>
# <td>사범대학관 지하1층</td>
# <td>혁신융합파크</td>
# </tr>
# <tr>
# <td>미래백년관 1층</td>
# <td>오름교육 Lounge</td>
# </tr>
# <tr>
# <td>제1공학관 1층</td>
# <td>SW Lounge</td>
# </tr>
# <tr>
# <td>학술정보관 1층</td>
# <td>Leading Lounge</td>
# </tr>
# <tr>
# <td>우편취급국</td>
# <td>학생회관 3층</td>
# <td>우편업무</td>
# </tr>
# <tr>
# <td rowspan="2">학생상담</td>
# <td>학생회관 3층</td>
# <td>인권센터</td>
# </tr>
# <tr>
# <td>학생회관 2층</td>
# <td>학생상담센터, 학생복지팀, 대학일자리플러스센터</td>
# </tr>
# <tr>
# <td rowspan="2">식당</td>
# <td>미래백년관 5층</td>
# <td>한식, 양식, 분식(구내식당)</td>
# </tr>
# <tr>
# <td>교수연구동 1층</td>
# <td>한식, 양식, 분식(구내식당)</td>
# </tr>
# <tr>
# <td>편의점</td>
# <td>사범대학관 지하 1층</td>
# <td>편의점</td>
# </tr>
# <tr>
# <td rowspan="3">카페</td>
# <td>미래백년관 5층</td>
# <td>커피, 음료</td>
# </tr>
# <tr>
# <td>미래백년관 지층</td>
# <td>커피, 음료</td>
# </tr>
# <tr>
# <td>중앙교수회관 1층</td>
# <td>커피, 음료</td>
# </tr>
# <tr>
# <td>기념품점</td>
# <td>학생회관 1층</td>
# <td>대학 기념품 및 기타</td>
# </tr>
# <tr>
# <td>복사기</td>
# <td>교내 곳곳</td>
# <td>복사 및 스캔(무인복사기) 운영</td>
# </tr>
# <tr>
# <td>구두수선소</td>
# <td>경영경제대학관 앞</td>
# <td>구두수선, 광택</td>
# </tr>
# <tr>
# <td rowspan="3">현금인출기</td>
# <td>학생회관 1층</td>
# <td>국민은행</td>
# </tr>
# <tr>
# <td>중앙교수회관 1층</td>
# <td>국민은행</td>
# </tr>
# <tr>
# <td>미래백년관 지층</td>
# <td>국민은행</td>
# </tr>
# <tr>
# <td>음료자동판매기</td>
# <td>교내 곳곳</td>
# <td>커피, 캔음료</td>
# </tr>
# <tr>
# <td rowspan="2">전시실</td>
# <td>미래백년관 지층</td>
# <td>전시 및 행사</td>
# </tr>
# <tr>
# <td>미술관 1층</td>
# <td>전시</td>
# </tr>
# <tr>
# <td rowspan="4">강당(공연장)</td>
# <td>문화예술관 1층 '계당홀'</td>
# <td>공연(대강당)</td>
# </tr>
# <tr>
# <td>문화예술관 지하 1층 '대신홀'</td>
# <td>공연(중강당)</td>
# </tr>
# <tr>
# <td>중앙교수회관 지하 1층 '소강당'</td>
# <td>공연(소강당)</td>
# </tr>
# <tr>
# <td>버스정류장 앞</td>
# <td>야외 공연장</td>
# </tr>
# <tr>
# <td>천마산수련원</td>
# <td>경기도 남양주</td>
# <td>학생수련시설</td>
# </tr>
# <tr>
# <td>대천수련원</td>
# <td>충남 대천</td>
# <td>학생수련시설</td>
# </tr>
# <tr>
# <td>증명서 발급</td>
# <td>학생회관 3층</td>
# <td>대학 관련 증명서 자동발급기</td>
# </tr>
# <tr>
# <td rowspan="4">세미나실</td>
# <td>경영경제대학관 1층 'CLP'</td>
# <td>5개실</td>
# </tr>
# <tr>
# <td>학술정보관 5층</td>
# <td>10개실</td>
# </tr>
# <tr>
# <td>미래백년관 지층 '카페'</td>
# <td>2개실(중·대세미나실)</td>
# </tr>
# <tr>
# <td>중앙교수회관 1층 '카페'</td>
# <td>3개실</td>
# </tr>
# <tr>
# <td rowspan="3">학생생활관</td>
# <td>스뮤하우스(평창동)</td>
# <td>학생 기숙사 시설(내국인)</td>
# </tr>
# <tr>
# <td>상명행복생활관(홍지동)</td>
# <td>학생 기숙사 시설(내국인)</td>
# </tr>
# <tr>
# <td>빌라하우스(홍지동)</td>
# <td>학생 기숙사 시설(내·외국인)</td>
# </tr>
# <tr>
# <td>학생회실</td>
# <td>학생회관 2층, 3층</td>
# <td>7개실</td>
# </tr>
# <tr>
# <td>동아리방</td>
# <td>학생회관 4층, 문화예술관 지하3층</td>
# <td>24개실(동아리방, 연습실)</td>
# </tr>
# <tr>
# <td>샤워장</td>
# <td>미래백년관(주차장) 2층</td>
# <td>샤워시설</td>
# </tr>
# </table>
#
# ==================================================
# Document id: YWJlY2JiOTAtMjQ4My00ZGFiLTgwMjAtNzdlNTgxYjNiNTM0
# Content: <!-- FigureContent="**Title**: Campus Map with Wi-Fi Access Points
# **ChartType**: treemap
# **TopicKeywords**: Access Points, Campus, Map, Wi-Fi
# **DetailedDescription**: The image is a map of a campus with various buildings marked. Each building is represented by a circle, with some circles outlined in red and others in blue. The legend at the top left corner indicates that red circles represent buildings with '전용AP 장비' (dedicated AP equipment) and blue circles represent buildings with '일반AP 장비' (general AP equipment). The map includes various buildings such as libraries, lecture halls, and administrative offices, each labeled in Korean. The map also features two cartoon characters at the bottom, adding a playful element to the design.
# **Summary**: The map provides a visual representation of a campus, highlighting the distribution of Wi-Fi access points across different buildings. Red circles indicate buildings with dedicated AP equipment, while blue circles indicate those with general AP equipment. This map is useful for understanding the Wi-Fi infrastructure on campus.
# **MarkdownDataTable**:
# **AxisTitles**
# **AxisTitles.xAxisTitle**:
# **AxisTitles.yAxisTitle**:
# **FootnotesAndAnnotations**: Legend:
# - Red circle: 전용AP 장비 (Dedicated AP equipment)
# - Blue circle: 일반AP 장비 (General AP equipment)
# " --><figure>
# 지문 깊
# : 외부AP 장비
# 홍지문 길
# 월해관
# 全
# ®
# : 건물AP 장비
# 贝
# 수회관
# P
# 주차장2
# 체육관
# 제2교수회관
# 운동장
# 합관
# 종합관
# 생활에출관
# 생활예술관
# 中
# 南
# 상명대학교사범대학
# 부속여자고등학교
# 계당을
# 以
# • 상명대학교
# 20
# 미술가정관
# 문호
# 글로벌문 화예술교육연구소
# 20
# 미래백년관
# 1
# 상명아트센터
# 상명아트센터
# 【2
# 12
# 红
# 1
# 월해갤러리
# 11
# 구
# 상명대학교사범
# 대학부속여자중학교
# 9
# 口
# 10
# 【2
# 7-1
# に
# 30
# 사범대학관
# 홍지문4길
# は
# 7
# 부
# ロ
# 학
# 7
# に
# 20m
# kakao
# 대학본부
# 司
# の
# 권고
# 무량사
# 26
# 행복을
# 뿌리는 판
# 12
# 27-6
# 상명
# 5
# 20
# 경영경제대학관
# 미이 엄관
# 17
# 27-5
# [
# 연구동별관
# 22
# 27-4
# 1
# 학술정보관
# 경영경제대학관
# A
# 门
# -홍지문2갈
# 관
# 학생회관
# 18
# n
# 18-1
# 29
# 口
# 日
# 7
# \+
# 종로
# ロ
# 시니어스
# 대
# は
# 27
# P
# 20-6
# 13
# 16
# 12
# 다
# 16
# 25
# 홍지문 길
# 대
# 真
# GS25
# 912
# 가
# F
# せ
# 지분3김
# 前
# 서교빌라
# 7
# 32
# 제1공학관
# ↓
# 6
# 国
# 角
# 고은빌라
# 홍지문 3김
# 6
# 今
# 중앙교수회관
# 홍지문2길
# 11
# 아리가또맘마
# 日
# に
# ワ
# 19
# F
# R
# ♡
# 네네치킨
# 前
# 유원빌라
# 9
# フ
# 宁
# 20
# 학대학관
# 홍지문2김
# ▼平
# 더함께식탁
# P
# C
# 茶
# 상명행복
# 어린이집
# 인문
# 인문사회과학대학관
# 會
# 홍지파크
# TP
# 빨간계단
# 227-32
# 7
# 2
# こ
# 6-3
# 江
# 지문2가길
# 中
# 리또리또
# 프루터
# 227-23
# 227-
# 이우진어소시
# 에이트
# 홍지문2강
# 园
# 日
# に
# 大
# 검
# 제1교스회관
# 227-17
# い
# 잘되는 집
# 홍지문1길
# 口
# 3-3
# 南
# 상명대학교
# 사범대학부속초등학교
# 8
# 千果
# 구
# 5
# .
# 제1교수회관
# 10
# 6
# 홍지문2가길
# 사학
# 구
# F
# 會
# 개미빌라
# 제2공학관
# F
# 1244
# 금성빌라
# 江
# 홍지문2가길
# 7
# 3-2
# F
# 2:盒+
# 12-6
# 12-6
# 상명사대부속
# 유치원
# 코즈스
# 12-6
# 12-6
# ロ
# 7
# 11
# 5-1
# 花
# 송암사,
# 12
# 홍지문 길
# R
# 12-6
# 6-12
# ●
# SMU
# SMU
# </figure>
#
# ==================================================

# %% [markdown]
# ## 🚀 Generate answer to query

# %%
# Define system prompt template for chat model
prompt = """
You are an expert in document analysis. You are proficient in reading and analyzing technical reports. You are good at numerical reasoning and have a good understanding of financial concepts. You are given a question which you need to answer based on the references provided. To answer this question, you may first read the question carefully to know what information is required or helpful to answer the question. Then, you may read the references to find the relevant information.

If you find enough information to answer the question, you can first write down your thinking process and then provide a concise answer at the end.
If you find that there is not enough information to answer the question, you can state that there is insufficient information.
If you are not able or sure how to answer the question, say that you are not able to answer the question.
Do not provide any information that is not present in the references.
References are in markdown format, you may follow the markdown syntax to better understand the references.
Responses should be in language that is same as the question.

---
References:
{context}
---

Now, here is the question:
---
Question:
{question}
---
Thinking Process::: 
Answer::: 
"""

# Helper function to generate the formatted context from each retrieved document
def generate_context(chunks):
    context = []
    for i, chunk in enumerate(chunks):
        s = (f'Source {i} Metadata: {chunk.metadata}\n'
                f'Source {i} Content: {chunk.page_content}')
        context.append(s)
    context = '\n---\n'.join(context)
    return context

# Remove redundant chunks
appeared = set()
unique_chunks = []
for chunk in retrieved_docs:
    chunk_id = chunk.metadata['id']
    if chunk_id not in appeared:
        appeared.add(chunk_id)
        unique_chunks.append(chunk)
context = generate_context(unique_chunks)

# Format the prompt with the provided query and formatted context
prompt = prompt.format(question=query,
                       context=context)

# %%
from langchain_openai import AzureChatOpenAI

chat_llm = AzureChatOpenAI(model=AZURE_OPENAI_CHAT_DEPLOYMENT_NAME,
                            azure_endpoint=AZURE_OPENAI_ENDPOINT,
                            azure_ad_token_provider=token_provider,
                            api_version=AZURE_OPENAI_CHAT_API_VERSION,
                            temperature=0.7)

# Print the LLM's answer to the query with the retrieved documents as additional context
answer = chat_llm.invoke(prompt)
print(answer.content)
# Out:
# ### Thinking Process:
# To answer the question about the Campus Map, I need to focus on the relevant information from the provided references. The references contain information about the service areas, specific facilities, and a description of the campus map related to Wi-Fi access points.
#
# 1. **Identify the purpose of the Campus Map**: It's mentioned that the map helps in understanding the distribution of Wi-Fi access points across different buildings.
# 2. **Check for details about the map's features**: The description includes color coding for different types of access points, namely red for dedicated AP equipment and blue for general AP equipment. Additionally, it cites various buildings present on the campus.
# 3. **Summarize the key points**: The explanations provided in the references highlight what one can expect to find on the campus map.
#
# ### Answer:
# Campus Map은 캠퍼스 내 다양한 건물의 위치와 Wi-Fi 접속 지점을 시각적으로 표현한 것입니다. 이 맵은 빨간 원이 '전용AP 장비'를 나타내고, 파란 원이 '일반AP 장비'를 나타내는 색상 코드로 구성되어 있어 각 건물의 Wi-Fi 인프라를 이해하는 데 유용합니다. 맵에는 도서관, 강의실, 행정 사무소 등 여러 건물이 표시되어 있습니다.
